# %%
import pickle
import pandas as pd

# %%
with open('/home/srinivas/Desktop/normal/bert_scores','rb') as f:
     bert_scores=pickle.load( f)

# %%
with open('/home/srinivas/Desktop/normal/fast_scores','rb') as f:
     fast_scores=pickle.load( f)

# %%
bert7=[]
for x in bert_scores:
    for y in x:
        bert7.append(y)

# %%
fast7=[]
for x in fast_scores:
    for y in x:
        fast7.append(y)

# %%
fast7.sort()

# %%
print(fast7)
# Out:
# [0.07857407, 0.07857407, 0.07994236, 0.07994236, 0.07994236, 0.07994236, 0.07994236, 0.07994236, 0.07994236, 0.07994236, 0.083446436, 0.083446436, 0.083446436, 0.083446436, 0.084008016, 0.084008016, 0.084008016, 0.084008016, 0.08555459, 0.08555459, 0.08555459, 0.08555459, 0.08555459, 0.08555459, 0.08555459, 0.08555459, 0.087572575, 0.087572575, 0.087572575, 0.087572575, 0.087572575, 0.087572575, 0.087572575, 0.087572575, 0.087572575, 0.087572575, 0.087572575, 0.087572575, 0.08876434, 0.08876434, 0.08876434, 0.08876434, 0.08876434, 0.09273358, 0.09273358, 0.09273358, 0.09273358, 0.09273358, 0.09273358, 0.09273358, 0.09273358, 0.09273358, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09320184, 0.09372287, 0.09372287, 0.09372287, 0.09372287, 0.09372287, 0.093
# ...

# %%
bert7.sort()

# %%
print(bert7)
# Out:
# [0.69040895, 0.69040895, 0.6924897, 0.6935972, 0.6935972, 0.69564515, 0.69564515, 0.69564515, 0.7005047, 0.70189774, 0.70189774, 0.70189774, 0.70598626, 0.7063816, 0.7063816, 0.7067884, 0.7067884, 0.7096441, 0.7096441, 0.74921185, 0.7634541, 0.7634541, 0.7634541, 0.7662959, 0.7662959, 0.7662959, 0.7662959, 0.7662959, 0.7662959, 0.76686347, 0.76686347, 0.76686347, 0.7693664, 0.7693664, 0.7693664, 0.7693664, 0.7693664, 0.7693664, 0.7695897, 0.7695897, 0.7695897, 0.7714947, 0.7714947, 0.7714947, 0.7714947, 0.7714947, 0.7714947, 0.7714947, 0.7714947, 0.7714947, 0.7844314, 0.7844314, 0.7844314, 0.7868668, 0.7868668, 0.7868668, 0.7868668, 0.7868668, 0.7868668, 0.7868668, 0.7868668, 0.7868668, 0.78705245, 0.7876368, 0.7876368, 0.7876368, 0.7880476, 0.7880476, 0.7887226, 0.7887226, 0.7887226, 0.7887226, 0.7887226, 0.7887226, 0.78896284, 0.78896284, 0.78920734, 0.78920734, 0.7897923, 0.7897923, 0.7897923, 0.7908257, 0.7908257, 0.7908257, 0.7914561, 0.7914561, 0.7914561, 0.7946716, 0.7946716, 
# ...

# %%
summer=0
for x in fast7:
    summer+=x
mean=summer/len(fast7)

# %%
mean
# Out:
# 0.8505905041768588

# %%
ranger=(fast7[-1]-fast7[0])

# %%
ranger
# Out:
# 0.9214259300000001

# %%
#analyse the length of the reviews
import matplotlib.pyplot as plt
# %matplotlib inline
#bert_len = [len(x) for x in bert7]
pd.Series(bert7).hist()
plt.show()
pd.Series(bert7).describe()
# Out:
# count    22550.000000
# mean         0.938802
# std          0.023883
# min          0.690409
# 25%          0.930903
# 50%          0.943134
# 75%          0.951992
# max          1.000000
# dtype: float64

# %%
#analyse the length of the reviews
#import matplotlib.pyplot as plt
# %matplotlib inline
#bert_len = [len(x) for x in bert7]
pd.Series(fast7).hist()
plt.show()
pd.Series(fast7).describe()
# Out:
# count    22550.000000
# mean         0.850591
# std          0.092706
# min          0.078574
# 25%          0.819576
# 50%          0.869906
# 75%          0.905241
# max          1.000000
# dtype: float64

# %%
a_=pd.Series(fast7).describe()

# %%
a_
# Out:
# count    22550.000000
# mean         0.850591
# std          0.092706
# min          0.078574
# 25%          0.819576
# 50%          0.869906
# 75%          0.905241
# max          1.000000
# dtype: float64

# %%
with open('/home/srinivas/Desktop/normal/w2v_scores','rb') as f:
     w2v_scores=pickle.load( f)

# %%
w2v7=[]
for x in w2v_scores:
    for y in x:
        w2v7.append(y)

# %%
w2v7.sort()
print(w2v7)
# Out:
# [0.15359245, 0.15488401, 0.15488401, 0.15488401, 0.15488401, 0.15488401, 0.15488401, 0.15488401, 0.15488401, 0.1562732, 0.1562732, 0.1562732, 0.1562732, 0.15868336, 0.15868336, 0.15868336, 0.15868336, 0.15868336, 0.15868336, 0.15868336, 0.15868336, 0.15868336, 0.15868336, 0.15868336, 0.15868336, 0.16167252, 0.16167252, 0.16167252, 0.16167252, 0.16304332, 0.16304332, 0.16304332, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16497763, 0.16544007, 0.16544007, 0.16544007, 0.16544007, 0.16544007, 0.1661092, 0.1661092, 0.1661092, 0.1661092, 0.1661092, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16701396, 0.16711031, 0.16711031
# ...

# %%
# %matplotlib inline
#bert_len = [len(x) for x in bert7]
pd.Series(w2v7).hist()
plt.show()
pd.Series(w2v7).describe()
# Out:
# count    22550.000000
# mean         0.744963
# std          0.129565
# min          0.153592
# 25%          0.691150
# 50%          0.768674
# 75%          0.829466
# max          1.000000
# dtype: float64

# %%
w2v_range=w2v7[-1]-w2v7[0]
print(w2v_range)
# Out:
# 0.84640755

# %%
with open('/home/srinivas/Desktop/normal/spacy_scores','rb') as f:
     spacy_scores=pickle.load( f)

# %%
spacy7=[]
for x in spacy_scores:
    for y in x:
        spacy7.append(y)

# %%
spacy7.sort()
print(spacy7)
# Out:
# [0.07006257, 0.07006257, 0.07006257, 0.07006257, 0.07135631, 0.07319208, 0.07319208, 0.08248525, 0.08248525, 0.08248525, 0.08640785, 0.08640785, 0.08640785, 0.08640785, 0.08640785, 0.08640785, 0.08640785, 0.08640785, 0.08640785, 0.08640785, 0.08640785, 0.08640785, 0.08640785, 0.08640785, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.08695901, 0.092344604, 0.092344604, 0.092344604, 0.092344604, 0.092344604, 0.092344604, 0.092344604, 0.092344604, 0.092344604, 0.092344604, 0.092344604, 0.092344604, 0.10513348, 0.10513348, 0.10513348, 0.10513348, 0.17780621, 0.17780621, 0.17780621, 0.17780621, 0.17780621, 0.17780621, 0.18404032, 0.18404032, 0.18404032, 0.18758032, 0.18758032, 0.18758032, 0
# ...

# %%
# %matplotlib inline
#bert_len = [len(x) for x in bert7]
pd.Series(spacy7).hist()
plt.show()
pd.Series(spacy7).describe()
# Out:
# count    22550.000000
# mean         0.830783
# std          0.105297
# min          0.070063
# 25%          0.795089
# 50%          0.855735
# 75%          0.896539
# max          1.000000
# dtype: float64

# %%
spacy_range=spacy7[-1]-spacy7[0]
print(spacy_range)
# Out:
# 0.92993743

# %%
with open('/home/srinivas/Desktop/normal/use_scores','rb') as f:
     use_scores=pickle.load( f)

# %%
use7=[]
for x in use_scores:
    for y in x:
        use7.append(y)

# %%
use7.sort()
print(use7)
# Out:
# [0.103960946, 0.103960946, 0.11300895, 0.11300895, 0.11300895, 0.11565082, 0.11565082, 0.11630118, 0.11739853, 0.11739853, 0.11739853, 0.12645745, 0.1388369, 0.1388369, 0.15267013, 0.1555471, 0.1555471, 0.1555471, 0.16490273, 0.16490273, 0.16490273, 0.16490273, 0.16490273, 0.16490273, 0.16630363, 0.17373651, 0.17373651, 0.17588429, 0.17588429, 0.17588429, 0.1762095, 0.17634559, 0.17634559, 0.17634559, 0.17634559, 0.17724909, 0.17724909, 0.18168586, 0.18168586, 0.18168586, 0.18731308, 0.18731308, 0.18927124, 0.18927124, 0.18927124, 0.19098933, 0.19098933, 0.19316307, 0.19316307, 0.19327015, 0.19327015, 0.19882275, 0.19901057, 0.19910084, 0.19910084, 0.20028892, 0.20028892, 0.20086521, 0.20293665, 0.20293665, 0.20439562, 0.20439562, 0.20439562, 0.20439562, 0.20439562, 0.20439562, 0.20497923, 0.20497923, 0.20497923, 0.20532669, 0.20532669, 0.20532669, 0.20532669, 0.20538993, 0.20862542, 0.21108072, 0.2113274, 0.21287555, 0.21316084, 0.21316084, 0.21316084, 0.21316084, 0.21317835, 0.2131
# ...

# %%
# %matplotlib inline
#bert_len = [len(x) for x in bert7]
pd.Series(use7).hist()
plt.show()
pd.Series(use7).describe()
# Out:
# count    22550.000000
# mean         0.701186
# std          0.135391
# min          0.103961
# 25%          0.650517
# 50%          0.733669
# 75%          0.793448
# max          1.000000
# dtype: float64

# %%
use_range=use7[-1]-use7[0]
print(use_range)
# Out:
# 0.8960390540000001

# %%
"source": "((Math.abs(cosineSimilarity(params.spacy_vector, doc['spacy_vector'])-0.8307))/0.9299)+((Math.abs(cosineSimilarity(params.w2v_vector, doc['w2v_vector'])-0.7449))/0.8464)+((Math.abs(cosineSimilarity(params.fasttext_vector, doc['fasttext_vector'])-0.8505))/0.92142)+((Math.abs(cosineSimilarity(params.bert_vector, doc['bert_vector'])-0.9388))/0.309511)+((Math.abs(cosineSimilarity(params.use_vector, doc['use_vector'])-0.70118))/0.8960)",
