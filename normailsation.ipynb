# %%
try:
    import elasticsearch
    from elasticsearch import Elasticsearch
    
    import pandas as pd
    import json
    from ast import literal_eval
    from tqdm import tqdm
    import datetime
    import os
    import sys
    
    import os
    import numpy as np
    import tensorflow as tf
    
    from elasticsearch import helpers
    
    from gensim.models import Word2Vec, KeyedVectors
    
    import nltk
    import re
    from nltk.corpus import stopwords
    nltk.download('stopwords')
    
    import spacy
    import pickle

    print("Loaded  .. . . . . . . .")
except Exception as E:
    print("Some Modules are Missing {} ".format(E))
# Out:
# Loaded  .. . . . . . . .
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/srinivas/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
with open("/home/srinivas/Desktop/dataframe/the_data.pkl",'rb') as f:
     df= pickle.load(f)

# %%
df
# Out:
#                                                    atom country  \
# 0     PLENDIL (felodipine) is a calcium ion influx i...  Canada
# 1     PLENDIL (felodipine) is a calcium ion influx i...  Canada
# 2     PLENDIL (felodipine) is a calcium ion influx i...  Canada
# 3     The therapeutic effect of this group of drugs ...  Canada
# 4     The therapeutic effect of this group of drugs ...  Canada
# ...                                                 ...     ...
# 2250  Description:\tLisinopril is a white to off-whi...  Canada
# 2251  Description:\tLisinopril is a white to off-whi...  Canada
# 2252  ZESTRIL is supplied as 5 mg, 10 mg and 20 mg t...  Canada
# 2253  ZESTRIL is supplied as 5 mg, 10 mg and 20 mg t...  Canada
# 2254  ZESTRIL is supplied as 5 mg, 10 mg and 20 mg t...  Canada
#
#                    product                                              query  \
# 0      Plendil(Felodipine)            What is a calcium ion influx inhibitor?
# 1      Plendil(Felodipine)  What class of calcium channel blockers is Felo...
# 2      Plendil(Felodipine)  Felodipine is a member of which class of inhib...
# 3      Plendil(Felodipine)  What is the therapeutic effect of Felodipine r...
# 4      Plendil(Felodipine)  How are the contractile processes of these tis...
# ...                    ...                                                ...
# 2250  Zestril (lisinopril)                Lisinospril is what kind of powder?
# 2251  Zestril (lisinopril)  What is the solublity of lisinopril in water ,...
# 2252  Zestril (lisinopril)  How many nonmedicinal ingredients does each ta...
# 2253  Zestril (lisinopril)                           How zestril is supplied?
# 2254  Zestril (lisinopril)  In addition to themedicinal ingredient lisinop...
#
#                                         fasttext_answer  \
# 0     [-0.11925999894738197, -0.009213333328564962, ...
# 1     [-0.11925999894738197, -0.009213333328564962, ...
# 2     [-0.11925999894738197, -0.009213333328564962, ...
# 3     [-0.051349122751210084, 0.0010666667520509738,...
# 4     [-0.051349122751210084, 0.0010666667520509738,...
# ...                                                 ...
# 2250  [-0.0022642851940223147, -0.0563214278081432, ...
# 2251  [-0.0022642851940223147, -0.0563214278081432, ...
# 2252  [-0.0632821427259062, 0.07050714363244229, 0.0...
# 2253  [-0.0632821427259062, 0.07050714363244229, 0.0...
# 2254  [-0.0632821427259062, 0.07050714363244229, 0.0...
#
#                                       fasttext_question  \
# 0     [-0.11014999728649855, 0.007775001227855682, 0...
# 1     [-0.10943333432078362, 0.006266666886707147, 0...
# 2     [-0.1116000022739172, -0.0011249997187405825, ...
# 3     [0.000200001522898674, 0.0321500007994473, 0.1...
# 4     [-0.02942222191227807, 0.038144443132397204, 0...
# ...                                                 ...
# 2250  [-0.0706000030040741, -0.026100000366568565, 0...
# 2251  [-0.025333331276973087, 0.0029333343263715506,...
# 2252  [-0.003475000150501728, 0.06787500320933759, -...
# 2253  [0.053599998354911804, -0.005100000184029341, ...
# 2254  [0.024049999192357063, 0.09005000005709007, 0....
#
#                                            w2v_question  \
# 0     [-0.06475830078125, 0.20947265625, -0.01521396...
# 1     [-0.09993489583333333, 0.004964192708333333, 0...
# 2     [-0.037353515625, 0.00390625, 0.048828125, 0.1...
# 3     [-0.06671142578125, 0.0811767578125, 0.0469970...
# 4     [-0.03811306423611111, 0.14531114366319445, 0....
# ...                                                 ...
# 2250  [0.05889892578125, -0.0111083984375, 0.1536865...
# 2251  [-0.15348307291666666, 0.030517578125, 0.07808...
# 2252  [0.0206146240234375, -0.06385498046875, -0.018...
# 2253  [-0.08154296875, -0.04296875, -0.0294189453125...
# 2254  [-0.0502197265625, 0.052880859375, 0.006845092...
#
#                                              w2v_answer  \
# 0     [-0.10657552083333334, 0.069140625, 0.02999191...
# 1     [-0.10657552083333334, 0.069140625, 0.02999191...
# 2     [-0.10657552083333334, 0.069140625, 0.02999191...
# 3     [-0.04052091899671053, 0.09128396552905702, 0....
# 4     [-0.04052091899671053, 0.09128396552905702, 0....
# ...                                                 ...
# 2250  [0.026881626674107144, 0.005759102957589286, 0...
# 2251  [0.026881626674107144, 0.005759102957589286, 0...
# 2252  [-0.12220869393184267, 0.04610153724407327, 0....
# 2253  [-0.12220869393184267, 0.04610153724407327, 0....
# 2254  [-0.12220869393184267, 0.04610153724407327, 0....
#
#                                             bert_answer  \
# 0     [-0.1021475, 0.19372933, -0.21815854, 0.206826...
# 1     [-0.1021475, 0.19372933, -0.21815854, 0.206826...
# 2     [-0.1021475, 0.19372933, -0.21815854, 0.206826...
# 3     [-0.07960795, 0.12230982, -0.2276642, -0.00896...
# 4     [-0.07960795, 0.12230982, -0.2276642, -0.00896...
# ...                                                 ...
# 2250  [-0.02737657, -0.07943635, -0.22290449, 0.0618...
# 2251  [-0.02737657, -0.07943635, -0.22290449, 0.0618...
# 2252  [-0.30811125, -0.2613501, 0.12829246, 0.490951...
# 2253  [-0.30811125, -0.2613501, 0.12829246, 0.490951...
# 2254  [-0.30811125, -0.2613501, 0.12829246, 0.490951...
#
#                                           bert_question  \
# 0     [0.2899235, -0.121713676, 0.24831414, 0.076035...
# 1     [-0.04205227, -0.019552507, 0.16107942, 0.3579...
# 2     [0.37489668, 0.033670336, -0.09372824, 0.08862...
# 3     [0.050525643, 0.058479086, 0.17381626, 0.10562...
# 4     [-0.14897719, 0.051382728, -0.06139521, 0.1016...
# ...                                                 ...
# 2250  [-0.044409927, -0.16870317, -0.15328597, 0.170...
# 2251  [-0.12186316, -0.09119643, -0.0061557903, 0.08...
# 2252  [-0.014567496, -0.5502859, -0.11594291, 0.0241...
# 2253  [0.08967239, -0.247079, 0.10820022, 0.20607254...
# 2254  [-0.08041984, -0.32411855, -0.089834794, 0.007...
#
#                                          spacy_question  \
# 0     [-0.24090976, 0.256362, 0.020495497, -0.099701...
# 1     [-0.012048334, 0.32869837, -0.0176391, -0.0020...
# 2     [0.028587498, 0.0662625, 0.1000235, 0.00710500...
# 3     [-0.0468025, 0.19192249, -0.19600251, -0.04838...
# 4     [-0.13795668, 0.115536675, -0.18193598, 0.0613...
# ...                                                 ...
# 2250  [-0.07918367, 0.24674332, 0.029136, -0.0801326...
# 2251  [-0.1330682, 0.274456, 0.14784399, -0.18872039...
# 2252  [-0.2269568, -0.0438104, -0.0284042, -0.053428...
# 2253  [0.160219, 0.221925, 0.40344, -0.42404, -0.433...
# 2254  [-0.180125, 0.2751647, 0.17029558, -0.24759814...
#
#                                            spacy_answer  \
# 0     [-0.088737875, 0.30348238, -0.027731512, -0.03...
# 1     [-0.088737875, 0.30348238, -0.027731512, -0.03...
# 2     [-0.088737875, 0.30348238, -0.027731512, -0.03...
# 3     [-0.072944276, 0.2486027, -0.19252801, 0.05586...
# 4     [-0.072944276, 0.2486027, -0.19252801, 0.05586...
# ...                                                 ...
# 2250  [-0.28126448, 0.22462204, -0.064237304, -0.127...
# 2251  [-0.28126448, 0.22462204, -0.064237304, -0.127...
# 2252  [-0.28531682, 0.17060298, 0.10772016, -0.13237...
# 2253  [-0.28531682, 0.17060298, 0.10772016, -0.13237...
# 2254  [-0.28531682, 0.17060298, 0.10772016, -0.13237...
#
#                                            use_question  \
# 0     [0.027756759896874428, 0.007806204259395599, -...
# 1     [0.0189292561262846, -0.021205231547355652, -0...
# 2     [0.02716185711324215, 0.0028547781985253096, -...
# 3     [0.04280677065253258, 0.031687188893556595, -0...
# 4     [0.003646381665021181, 0.06274382770061493, -0...
# ...                                                 ...
# 2250  [-0.01625431887805462, -0.01952160708606243, -...
# 2251  [-0.030599063262343407, -0.013630962930619717,...
# 2252  [0.003697506617754698, -0.018902074545621872, ...
# 2253  [0.060909565538167953, 0.033695995807647705, -...
# 2254  [0.036186568439006805, -0.02454044111073017, -...
#
#                                              use_answer
# 0     [0.04650423303246498, 0.03865881636738777, -0....
# 1     [0.04650423303246498, 0.03865881636738777, -0....
# 2     [0.04650423303246498, 0.03865881636738777, -0....
# 3     [0.040527839213609695, 0.058647628873586655, -...
# 4     [0.040527839213609695, 0.058647628873586655, -...
# ...                                                 ...
# 2250  [0.01344585232436657, 0.01354377530515194, -0....
# 2251  [0.01344585232436657, 0.01354377530515194, -0....
# 2252  [0.015464583411812782, 0.0336962565779686, 0.0...
# 2253  [0.015464583411812782, 0.0336962565779686, 0.0...
# 2254  [0.015464583411812782, 0.0336962565779686, 0.0...
#
# [2255 rows x 14 columns]

# %%
country=df["country"]
country_set=set(country)
product=df["product"]
product_set=set(product)
print("countries : "+str(country_set))
print("products : "+str(product_set))
# Out:
# countries : {'Canada', 'European Union', 'United States'}
# products : {'Plendil(Felodipine)', 'Zestril (lisinopril)', 'Rosuvastatin(Crestor)'}

# %%
fast_answer=df["fasttext_answer"]

# %%
len(fast_answer)
# Out:
# 2255

# %%
w2v_answer=df["w2v_answer"]

# %%
len(w2v_answer)
# Out:
# 2255

# %%
spacy_answer=df["spacy_answer"]

# %%
len(spacy_answer)
# Out:
# 2255

# %%
bert_answer=df["bert_answer"]

# %%
len(bert_answer)
# Out:
# 2255

# %%
use_answer=df["use_answer"]

# %%
len(use_answer)
# Out:
# 2255

# %%
answer=df["atom"]

# %%
len(answer)
# Out:
# 2255

# %%
country_rec=df["country"]

# %%
len(country_rec)
for i in range(0,len(country_rec)):
    country_rec[i]=country_rec[i].lower()

# %%
country_rec[0]
# Out:
# 'canada'

# %%
product_rec=df["product"]

# %%
len(product_rec)
# Out:
# 2255

# %%
for i in range(0,len(product_rec)):
    product_rec[i]=product_rec[i].lower()
product_rec[0]
# Out:
# 'plendil(felodipine)'

# %%
print(tf.__version__)
# Out:
# 1.15.0-rc1

# %%
Settings = {
   "settings":{
      "number_of_shards":1,
      "number_of_replicas":0
   },
   "mappings":{
       "dynamic": "true",
        "_source": {
        "enabled": "true"
        },
       "properties":{
            "answer": {
            "type": "text"
            },
          "fasttext_vector":{
         "type":"dense_vector",
         "dims":300
      },
        "w2v_vector":{
         "type":"dense_vector",
         "dims":300
      },
        "spacy_vector":{
         "type":"dense_vector",
         "dims":300
      },
        "bert_vector":{
         "type":"dense_vector",
         "dims":768
      },
        "use_vector":{
         "type":"dense_vector",
         "dims":512
      },
          "country":{  
            "type":"text"
         },   
          "product":{  
            "type":"text"
         }
    }
   }
}

# %%
ENDPOINT = "http://localhost:9200/"
es = Elasticsearch(timeout=600,hosts=ENDPOINT)
print("python client created")
# Out:
# python client created

# %%
#creating the database
IndexName = 'the_final_ensemble'
my = es.indices.create(index=IndexName, ignore=[400,404], body=Settings)

# %%
my
# Out:
# {'error': {'root_cause': [{'type': 'resource_already_exists_exception',
#     'reason': 'index [the_final_ensemble/gOJq7_GcTAGGo4c8JEVZoQ] already exists',
#     'index_uuid': 'gOJq7_GcTAGGo4c8JEVZoQ',
#     'index': 'the_final_ensemble'}],
#   'type': 'resource_already_exists_exception',
#   'reason': 'index [the_final_ensemble/gOJq7_GcTAGGo4c8JEVZoQ] already exists',
#   'index_uuid': 'gOJq7_GcTAGGo4c8JEVZoQ',
#   'index': 'the_final_ensemble'},
#  'status': 400}

# %%
df.columns
# Out:
# Index(['atom', 'country', 'product', 'query', 'fasttext_answer',
#        'fasttext_question', 'w2v_question', 'w2v_answer', 'bert_answer',
#        'bert_question', 'spacy_question', 'spacy_answer', 'use_question',
#        'use_answer'],
#       dtype='object')

# %%
arr=[]
for i in range(0,len(answer)):
     arr.append({
    'answer':answer[i],
    'fasttext_vector':fast_answer[i],
    'w2v_vector':w2v_answer[i],
    'spacy_vector':spacy_answer[i],
    'bert_vector':bert_answer[i],
    'use_vector':use_answer[i],
    'country':country_rec[i].lower().strip(),
    'product':product_rec[i].lower().strip()})

# %%
len(arr)
# Out:
# 2255

# %%
for i in range(0,len(arr)):

    resp=es.index(index=IndexName,doc_type="_doc",id=i,body=arr[i])

# %%
resp
# Out:
# {'_index': 'the_final_ensemble',
#  '_type': '_doc',
#  '_id': '2254',
#  '_version': 1,
#  'result': 'created',
#  '_shards': {'total': 1, 'successful': 1, 'failed': 0},
#  '_seq_no': 2254,
#  '_primary_term': 1}

# %%
que="what is Crestor used for in canada?"
print(que)
temp_prod=df["product"]
temp_country=df["country"]
product_list=list(set(temp_prod))
print(product_list)
country_list=list(set(temp_country))
print(country_list)
# Out:
# what is Crestor used for in canada?
# ['rosuvastatin(crestor)', 'plendil(felodipine)', 'zestril (lisinopril)']
# ['european union', 'united states', 'canada']

# %%
def list_generator():    
    temp_prod=df["product"]
    temp_country=df["country"]

    product_list=list(set(temp_prod))
    country_list=list(set(temp_country))

    for i in range(0,len(product_list)):
        product_list[i]=product_list[i].lower()

    for i in range(0,len(country_list)):
        country_list[i]=country_list[i].lower().strip()

    prods=[]

    for x in product_list:
        temp=x.split("(")
        for i in range(0,len(temp)):
            temp[i]=temp[i].replace(")","")
            temp[i]=temp[i].strip()
            prods.append(temp[i])
    return [prods,country_list]

# %%
list_generator()
# Out:
# [['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril'],
#  ['european union', 'united states', 'canada']]

# %%
global spacy_question
spacy_question=df["spacy_question"]
print(len(spacy_question))
print(len(spacy_question[0]))
# Out:
# 2255
# 300

# %%
global bert_question
bert_question=df["bert_question"]
print(len(bert_question))
print(len(bert_question[0]))
# Out:
# 2255
# 768

# %%
global fasttext_question
fasttext_question=df["fasttext_question"]
print(len(fasttext_question))
print(len(fasttext_question[0]))
# Out:
# 2255
# 300

# %%
global w2v_question
w2v_question=df["w2v_question"]
print(len(w2v_question))
print(len(w2v_question[0]))
# Out:
# 2255
# 300

# %%
global use_question
use_question=df["use_question"]
print(len(use_question))
print(len(use_question[0]))
# Out:
# 2255
# 512

# %%
        "source": "(((Math.abs(cosineSimilarity(params.spacy_vector, doc['spacy_vector'])-0.8307)))+((Math.abs(cosineSimilarity(params.w2v_vector, doc['w2v_vector'])-0.7449)))+((Math.abs(cosineSimilarity(params.fasttext_vector, doc['fasttext_vector'])-0.8505)))+((Math.abs(cosineSimilarity(params.bert_vector, doc['bert_vector'])-0.9388)))+((Math.abs(cosineSimilarity(params.use_vector, doc['use_vector'])-0.70118))))/5",

# %%
def query_creator(que,lists,index): 
    global spacy_question
    global use_question
    global w2v_question
    global fasttext_question
    global bert_question
    prods=lists[0]
    country_list=lists[1]
    print(prods)
    print(country_list)
    
    spacy_vec=spacy_question[index]
    w2v_vec=w2v_question[index]
    fasttext_vec=fasttext_question[index]
    bert_vec=bert_question[index]
    use_vec=use_question[index]
    #print(que_vec)
    #print(que)
    que=que.lower()
    p=""
    c=""
    for x in prods:
        if x in que:
            p=x
            print(p)
            break
    for x in country_list:
        if x in que:
            c=x
            print(c)

    script_query={}
    if p!="" and c!="":
        print("1...........")
        script_query = {
        "script_score": {
        "query": {
    "bool": {
      "must": [
        {
          "match": {
            "product": p
          }
        }
      ],
      "should": [
        {
          "match": {
            "country": c
          }
        }
      ]
    }
  },
        "script": {
        "source": "(((Math.abs(cosineSimilarity(params.spacy_vector, doc['spacy_vector'])-0.8307)))+((Math.abs(cosineSimilarity(params.w2v_vector, doc['w2v_vector'])-0.7449)))+((Math.abs(cosineSimilarity(params.fasttext_vector, doc['fasttext_vector'])-0.8505)))+((Math.abs(cosineSimilarity(params.bert_vector, doc['bert_vector'])-0.9388)))+((Math.abs(cosineSimilarity(params.use_vector, doc['use_vector'])-0.70118))))/5",
        "params": {"spacy_vector": spacy_vec,"w2v_vector": w2v_vec,"fasttext_vector": fasttext_vec,"bert_vector": bert_vec,"use_vector": use_vec}
        }}}

    elif p!="" and c=="":
        print("2...........")
        script_query = {
        "script_score": {
        "query": {"match": {
              "product": {
                "query":p
              }}},
        "script": {
        "source": "(((Math.abs(cosineSimilarity(params.spacy_vector, doc['spacy_vector'])-0.8307)))+((Math.abs(cosineSimilarity(params.w2v_vector, doc['w2v_vector'])-0.7449)))+((Math.abs(cosineSimilarity(params.fasttext_vector, doc['fasttext_vector'])-0.8505)))+((Math.abs(cosineSimilarity(params.bert_vector, doc['bert_vector'])-0.9388)))+((Math.abs(cosineSimilarity(params.use_vector, doc['use_vector'])-0.70118))))/5",
        "params": {"spacy_vector": spacy_vec,"w2v_vector": w2v_vec,"fasttext_vector": fasttext_vec,"bert_vector": bert_vec,"use_vector": use_vec}
        }}}
    elif p=="" and c!="":
        print("3...........")
        script_query = {
        "script_score": {
        "query": {"match": {
              "country": {
                "query":c
              }}},
        "script": {
        "source": "(((Math.abs(cosineSimilarity(params.spacy_vector, doc['spacy_vector'])-0.8307)))+((Math.abs(cosineSimilarity(params.w2v_vector, doc['w2v_vector'])-0.7449)))+((Math.abs(cosineSimilarity(params.fasttext_vector, doc['fasttext_vector'])-0.8505)))+((Math.abs(cosineSimilarity(params.bert_vector, doc['bert_vector'])-0.9388)))+((Math.abs(cosineSimilarity(params.use_vector, doc['use_vector'])-0.70118))))/5",
        "params": {"spacy_vector": spacy_vec,"w2v_vector": w2v_vec,"fasttext_vector": fasttext_vec,"bert_vector": bert_vec,"use_vector": use_vec}
        }}}
    else:
        print("4...........")
        script_query = {
        "script_score": {
        "query": {"match_all": {}},
        "script": {
        "source": "(((Math.abs(cosineSimilarity(params.spacy_vector, doc['spacy_vector'])-0.8307)))+((Math.abs(cosineSimilarity(params.w2v_vector, doc['w2v_vector'])-0.7449)))+((Math.abs(cosineSimilarity(params.fasttext_vector, doc['fasttext_vector'])-0.8505)))+((Math.abs(cosineSimilarity(params.bert_vector, doc['bert_vector'])-0.9388)))+((Math.abs(cosineSimilarity(params.use_vector, doc['use_vector'])-0.70118))))/5",
        "params": {"spacy_vector": spacy_vec,"w2v_vector": w2v_vec,"fasttext_vector": fasttext_vec,"bert_vector": bert_vec,"use_vector": use_vec}
        }}}
    return  script_query

# %%
lists=list_generator()

# %%
lists
# Out:
# [['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril'],
#  ['european union', 'united states', 'canada']]

# %%
que=df["query"][0]
que
# Out:
# 'What is a calcium ion influx inhibitor?'

# %%
script_query=query_creator(que,lists,0)
script_query
# Out:
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
#      -0.03180469572544098,
#      0.00160305667668581,
#      0.021977907046675682,
#      0.04497940465807915,
#      0.07965362071990967,
#      -0.0585155226290226,
#      0.039727721363306046,
#      0.04815274849534035,
#      0.01703961379826069,
#      -0.055155251175165176,
#      0.07890725880861282,
#      0.07628924399614334,
#      -0.009066352620720863,
#      -0.07585642486810684,
#      -0.005985567346215248,
#      -0.03382481262087822,
#      -0.02103772945702076,
#      0.0408502072095871,
#      -0.08357669413089752,
#      0.005883417557924986,
#      -0.056403160095214844,
#      0.03887273371219635,
#      0.01075169537216425,
#      -0.02513631246984005,
#      0.04516330361366272,
#      -0.04106169939041138,
#      0.03146662190556526,
#      0.07968441396951675,
#      -0.015495294705033302,
#      0.049276646226644516,
#      0.019249847158789635,
#      0.04568155109882355,
#      0.016028739511966705,
#      -0.022010818123817444,
#      0.053980953991413116,
#      -0.055382486432790756,
#      -0.0483599416911602,
#      -0.04053889960050583,
#      -0.022793443873524666,
#      -0.005464385263621807,
#      0.05912090465426445,
#      0.012396380305290222,
#      -0.040598999708890915,
#      0.043491315096616745,
#      -0.013585146516561508,
#      -0.06002402305603027,
#      0.052462320774793625,
#      -0.0008092840434983373,
#      -0.0770297572016716,
#      -0.00798732042312622,
#      0.028101075440645218,
#      -0.007309806067496538,
#      -0.04987690970301628,
#      -0.003518319921568036,
#      -0.04308386892080307,
#      0.04346581920981407,
#      0.03678394854068756,
#      -0.044975653290748596,
#      0.03503803163766861]}}}}

# %%
ans=es.search(index=IndexName,body={"size": 10,"query": script_query,"_source": {"includes": ["answer","country","product"]}})

# %%
ans
# Out:
# {'took': 125,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 2255, 'relation': 'eq'},
#   'max_score': 0.46329686,
#   'hits': [{'_index': 'the_final_ensemble',
#     '_type': '_doc',
#     '_id': '1853',
#     '_score': 0.46329686,
#     '_source': {'country': 'european union',
#      'product': 'zestril (lisinopril)',
#      'answer': 'ATC code: C09A A03.'}},
#    {'_index': 'the_final_ensemble',
#     '_type': '_doc',
#     '_id': '1053',
#     '_score': 0.37016562,
#     '_source': {'country': 'canada',
#      'product': 'rosuvastatin(crestor)',
#      'answer': 'CRESTOR may be taken in the morning or evening, with or without food.'}},
#    {'_index': 'the_final_ensemble',
#     '_type': '_doc',
#     '_id': '1054',
#     '_score': 0.37016562,
#     '_source': {'country': 'canada',
#      'product': 'rosuvastatin(crestor)',
#      'answer': 'CRESTOR may be taken in the morning or evening, with or without food.'}},
#    {'_index': 'the_final_ensemble',
#     '_type': '_doc',
#     '_id': '640',
#     '_score': 0.3658487,
#     '_source': {'country': 'european union',
#      'product': 'rosuvastatin(crestor)',
#      'answer': 'Paediatric use should only be carried out by specialists.'}},
#    {'_index': 'the_final_ensemble',
#     '_type': '_doc',
#     '_id': '209',
#     '_score': 0.35805935,
#     '_source': {'country': 'canada',
#      'product': 'plendil(felodipine)',
#      'answer': 'NOTE: These extended release tablets must not be divided, crushed or chewed.'}},
#    {'_index': 'the_final_ensemble',
#     '_type': '_doc',
#     '_id': '210',
#     '_score': 0.35805935,
#     '_source': {'country': 'canada',
#      'product': 'plendil(felodipine)',
#      'answer': 'NOTE: These extended release tablets must not be divided, crushed or chewed.'}},
#    {'_index': 'the_final_ensemble',
#     '_type': '_doc',
#     '_id': '211',
#     '_score': 0.35805935,
#     '_source': {'country': 'canada',
#      'product': 'plendil(felodipine)',
#      'answer': 'NOTE: These extended release tablets must not be divided, crushed or chewed.'}},
#    {'_index': 'the_final_ensemble',
#     '_type': '_doc',
#     '_id': '612',
#     '_score': 0.34812328,
#     '_source': {'country': 'united states',
#      'product': 'plendil(felodipine)',
#      'answer': 'Pink, circular, biconvex, film coated, engraved A/Fm on one side and 5 on the other. Diameter 9 mm. Packs of 30 tablets.'}},
#    {'_index': 'the_final_ensemble',
#     '_type': '_doc',
#     '_id': '633',
#     '_score': 0.3444973,
#     '_source': {'country': 'european union',
#      'product': 'rosuvastatin(crestor)',
#      'answer': 'Crestor may be given at any time of day, with or without food.'}},
#    {'_index': 'the_final_ensemble',
#     '_type': '_doc',
#     '_id': '634',
#     '_score': 0.3444973,
#     '_source': {'country': 'european union',
#      'product': 'rosuvastatin(crestor)',
#      'answer': 'Crestor may be given at any time of day, with or without food.'}}]}}

# %%
def questions():
    count=0
    que_arr=[]
    for x in df["query"]:
        sent=x.split("\n")
        for q in sent:
            if re.search('[a-zA-Z]',q)!=None:
                que_arr.append([q,count])
        count+=1
    return que_arr

# %%
que_arr=questions()

# %%
len(que_arr)
# Out:
# 2255

# %%
que_arr
# Out:
# [['What is a calcium ion influx inhibitor?', 0],
#  ['What class of calcium channel blockers is Felodipine a member of?', 1],
#  ['Felodipine is a member of which class of inhibitors?', 2],
#  ['What is the therapeutic effect of Felodipine related to?', 3],
#  ['How are the contractile processes of these tissues dependent upon the movement of extracellular calcium into the cells?',
#   4],
#  ['How does Felodipine blocks transmembrane influx of calcium ?', 5],
#  ['Through what channel Felodipine blocks transmembrane influx of calcium ?',
#   6],
#  ['What process results in a reduction of free calcium ions available within cells of the tissues like cardiac muscle and vascular smooth muscle',
#   7],
#  ['What does Felodipine do not alter?', 8],
#  ['In vitro studies show that the effects of what on contractile mechanisms are selective?',
#   9],
#  ['What is the effect on vascular smooth muscle?', 10],
#  ['Negative inotropic effects can be detected in what animal?', 11],
#  ['How Negative inotropic effects of felodipine can be detected', 12],
#  ['Does the Negative inotropic effects of felodipine are seen in animals?',
#   13],
#  ['Are the effects of felodipine on contractile mechanisms selective ?', 14],
#  ['What is the effect of felodipine on blood pressure in man?', 15],
#  ['What is a result of a dose-related decrease in peripheral vascular resistance?',
#   16],
#  ['On what the effect of felodipine on blood pressure in man is principally a consequence of ?',
#   17],
#  ['What is completely absorbed from the gastrointestinal tract after oral administration?',
#   18],
#  ['What is the systemic availability of felodipine due to rapid biotransformation during its first pass through the portal circulation?',
#   19],
#  ['Why the systemic availability felodipine is approximately 15% ?', 20],
#  ['Is the systemic availability felodipine is dependent on dose range?', 21],
#  ['What is the percentage of plasma protein binding of felodipine ?', 22],
#  ['How is Felodipine metabolized in the liver?', 23],
#  ['How many metabolites have been identified?', 24],
#  ['What percentage of a given dose is excreted in the urine?', 25],
#  ['What percentage of a given dose of felodipine is excreted in the urine?',
#   26],
#  ['What percentage of a given dose of felodipine is excreted in the feces.',
#   27],
#  ['How much percentage of felodipine is recovered unchanged in the urine', 28],
#  ['Does the felodipine metabolites have significant vasodilating activity ?',
#   29],
#  ['What prolongs the absorption phase of felodipine? The area under the plasma concentration versus time curve and Cmax are linearly related to what?',
#   30],
#  ['What is the mean Cmax at steady state?', 31],
#  ['How long does the mean tmax of felodipine range ?', 32],
#  ['What is the percentage of mean Cmax Following administration of PLENDIL to hypertensive patients',
#   33],
#  ['Does the increase in the AUC is found during multiple dosing of PLENDIL',
#   34],
#  ['How much is the inter-individual variation in Cmax and AUC after repeated dosing of PLENDIL?',
#   35],
#  ['What is not influenced by the presence of food in the gastrointestinal tract?',
#   36],
#  ['What is increased by 1.5 to 2 fold when PLENDIL is taken after a high fat or high carbohydrate meal versus fasting?',
#   37],
#  ['How does Cmax increase in blood pressure?', 38],
#  ['Why PLENDIL should not be administered with meals rich in carbohydrate or fat ?',
#   39],
#  ['Is the absorption characteristics of felodipine affected when PLENDIL is administered with a light meal?',
#   40],
#  ['How many times did the administration of a single dose of plain felidipine tablets increase as compared to administration with water?',
#   41],
#  ['What does the Studies in healthy male volunteers showed during PLENDIL administration',
#   42],
#  ['What happened following the administration of a single dose of plain felodipine 5 mg tablets with 200 mL grapefruit juice',
#   43],
#  ['What is the average clearance of felodipine in elderly hypertensives?', 44],
#  ['What percentage of the clearance in elderly volunteers was at steady state?',
#   45],
#  ['Does the Plasma concentrations of felodipine, after a single dose and at steady state, increase with age ?',
#   46],
#  ['In which group of patients the clearance of felodipine was reduced to about 60 percent ?',
#   47],
#  ['What does not alter the plasma concentration profile of felodipine?', 48],
#  ['What causes higher concentrations of metabolites to be present in the plasma?',
#   49],
#  ['Which impairment does not alter the plasma concentration profile of felodipine',
#   50],
#  ['Animal studies have demonstrated that what crosses the blood-brain barrier and the placenta?',
#   51],
#  ['What type of barrier does felodipine cross?', 52],
#  ['Does felodipine crosses the blood-brain barrier and the placenta.', 53],
#  ['What is the acute hemodynamic effect of felodipine?', 54],
#  ['What leads to a decrease in blood pressure associated with a modest reflex increase in heart rate?',
#   55],
#  ['How many beats per minute may be seen during chronic administration?', 56],
#  ['When does the reflex increase in heart rate frequently occurs', 57],
#  ['The effect on the heart rate is inhibited by what agents during felodipine therapy?',
#   58],
#  ['Within what time a reduction in blood pressure generally Following administration of PLENDIN?',
#   59],
#  ['How long does substantial blood pressure control last during chronic administration?',
#   60],
#  ['What percentage of diastolic blood pressure was reduced at peak plasma levels?',
#   61],
#  ['How does the antihypertensive effect correlate with the plasma concentration of felodipine?',
#   62],
#  ['During chronic administration of , substantial blood pressure control lasts for approximately how many hours?',
#   63],
#  ['Does Felodipine in therapeutic doses has any effect on conduction in the conducting system of the heart',
#   64],
#  ['Does Felodipine in therapeutic doses has any effect on the A-V nodal refractoriness',
#   65],
#  ['What happens when beta-blockade are given concomitantly with PLENDIL', 66],
#  ['What is decreased by felodipine while glomerular filtration rate remains unchanged?',
#   67],
#  ['Mild diuresis', 68],
#  ['natriuresis and kaliuresis have been observed during what week of therapy?',
#   69],
#  ['Is there any effects on serum electrolytes have been observed during short and long-term therapy with felodipine?',
#   70],
#  ['Does general salt and water retention occurs during therapy with felodipine',
#   71],
#  ['Is any increase in noradrenaline plasma levels have been observed during therapy with felodipine',
#   72],
#  ['What is indicated in the treatment of mild to moderate essential hypertension?',
#   73],
#  ['PLENDIL (felodipine) is indicated for what treatment?', 74],
#  ['In which patients PLENDIL should normally be used ?', 75],
#  ['What treatment is recommended for patients who has been associated with unacceptable adverse effects ?',
#   76],
#  ['What can be tried as an initial agent in patients in whom the use of diuretics and/or beta-blockers is contraindicated?',
#   77],
#  ['In which patients PLENDIL can be tried as an initial agent', 78],
#  ['Combination of PLENDIL with a thiazide diuretic or a beta-blocker has been found to be compatible and showed what?',
#   79],
#  ['Safety and efficacy of concurrent use of what with other antihypertensive agents has not been established?',
#   80],
#  ['What is the effect of Combination of PLENDIL with a thiazide diuretic or a beta-blocker ?',
#   81],
#  ['What does the Studies in pregnant rabbits administered doses of 0.46, 1.2, 2.3 and 4.6 mg/kg/day of felodipine showed?',
#   82],
#  ['What was observed in a teratology study in Cynomolgus monkeys?', 83],
#  ['What percentage of the fetuses had an abnormal position of the distal phalanges in about 40 percent?',
#   84],
#  ['What are the results of a teratology study in Cynomolgus monkeys', 85],
#  ['In which patuent group prolongation of parturition with difficult labour and an increased frequency of fetal and early postnatal deaths were observed during zestril treatment?',
#   86],
#  ['In what dosage range Significant enlargement of the mammary glands in excess of the normal enlargement for pregnant rabbits was found',
#   87],
#  ['Is changes in the mammary glands were not observed in rats or monkeys dueing zestril sudy?',
#   88],
#  ['What is PLENDIL?', 89],
#  ['What is the name of a beta-blocker used in hypertensive patients with compromised ventricular function?',
#   90],
#  ['How many patients with heart failure treated with felodipine have not shown negative inotropic effects?',
#   91],
#  ['Are there any established safety and efficacy of PLENDIL (felodipine) in patients with heart failure',
#   92],
#  ['Why caution should be exercised when using PLENDIL in hypertensive patients with compromised ventricular function',
#   93],
#  ['Are there any effects in Acute hemodynamic studies in a small number of patients with New York Heart Association Class II or III heart failure treated with felodipine',
#   94],
#  ['What may precipitate symptomatic hypotension and rarely syncope?', 95],
#  ['Careful monitoring of blood pressure during initial administration and titration of what is recommended?',
#   96],
#  ['In which patients PLENDIL may lead to reflex tachycardia', 97],
#  ['What should be taken to avoid hypotension especially in patients with a history of cerebrovascular insufficiency?',
#   98],
#  ['In which patients taking PLENDIL Care should be taken to avoid hypotension',
#   99],
#  ['What does PLENDIL give no protection against?', 100],
#  ['Does PLENDIL give any protection against the dangers of abrupt beta-blocker withdrawal',
#   101],
#  ['What should be used with caution in the presence of left ventricular outflow obstruction?',
#   102],
#  ['In presence of what PLENDIL should be used with caution', 103],
#  ['Along with leucocytoclastic vasculitis', 104],
#  ['what other event has been observed?', 105],
#  ['Which are the other dermatologic events which have been observed during PLENDIL treatment?',
#   106],
#  ['PLENDIL with drugs that result in strong inhibition of CYP3A4 can lead to what?',
#   107],
#  ['What can increase plasma levels of felodipine and associated serious adverse events?',
#   108],
#  ['What happens on Use of PLENDIL with drugs that result in strong inhibition of CYP3A4, such as ketoconazole, clarithromycin, ritonavir',
#   109],
#  ['What was the odds ratio of felodipine used concomitantly with azithromycin?',
#   110],
#  ['What happens when felodipine was used concomitantly with clarithromycin in elderly patients',
#   111],
#  ['What was the most common adverse event in clinical trials?', 112],
#  ['How much was the incidence of peripheral edema dose-dependent?', 113],
#  ['Which is most common Adverse reaction during PLENDIL treatment?', 114],
#  ['What was the Frequency of peripheral edema during plendil treatment?', 115],
#  ['Why Care should be taken to differentiate peripheral edema PLENDIL treatment?',
#   116],
#  ['Why Patients over 65 years of age may require lower doses of PLENDIL', 117],
#  ['What are the PLENDIL dosage consideration in elderly?', 118],
#  ['Why the Patients with impaired liver function may require lower doses of Plendil?',
#   119],
#  ['What are the PLENDIL dosage consideration in Patients with impaired liver function',
#   120],
#  ['What can induce gingival enlargement in patients with pronounced gingivitis and periodontitis?',
#   121],
#  ['What can be avoided or reversed by measures of good oral hygiene and mechanical debridement of the teeth?',
#   122],
#  ['In which patients PLENDIL can induce gingival enlargement', 123],
#  ['By what measure gingival enlargement can be avoided or reversed', 124],
#  ['Can PLENDIL cause gingivitis.', 125],
#  ['Why is PLENDIL not recommended in children?', 126],
#  ['What is not recommended for children because safety and efficacy are not established?',
#   127],
#  ['Why PLENDIL is not recommended in children', 128],
#  ['Grapefruit juice should be avoided before or during what treatment?', 129],
#  ['What the Published data on PLENDIL show', 130],
#  ['Why the consumption of grapefruit juice prior to or during treatment with PLENDIL should be avoided',
#   131],
#  ['What contains lactose?', 132],
#  ['What should not be given to patients with hereditary galactose intolerance?',
#   133],
#  ['Can PLENDIL be given to patients with hereditary galactose intolerance or glucose-galactose malabsorption.',
#   134],
#  ['What happens on Coadministration of felodipine with other drugs which follow biotransformation by the cytochrome P- 450 system',
#   135],
#  ['In which patients dosage may require adjustment when starting or stopping concomitantly administered felodipine to maintain optimum therapeutic blood levels.',
#   136],
#  ['What drug is known to be substrates of the cytochrome P-450 system?', 137],
#  ['Wh', 138],
#  ['What are the Drugs known to be substrates of the cytochrome P-450 system',
#   139],
#  ['What drugs are known to be inhibitors of the cytochrome P-450 system?',
#   140],
#  ['Which are the Drugs known to be inhibitors of the cytochrome P-450 system',
#   141],
#  ['Which have been shown to cause an increase in felodipine plasma concentrations',
#   142],
#  ['What happens when felodipine was given concomitantly with indomethacin or spironolactone.',
#   143],
#  ['How many folds did the AUC and Cmax increase in grapefruit juice?', 144],
#  ['What are the results of Coadministration of felodipine with grapefruit juice',
#   145],
#  ['How many patients with essential hypertension treated once daily with 2.5 to 10 mg PLENDIL (felodipine) as monotherapy?',
#   146],
#  ['What were the most common clinical adverse events?', 147],
#  ['Which is the most common adverse events In 861 patients with essential hypertension treated once daily with 2.5 to 10 mg PLENDIL',
#   148],
#  ['In which patients there is a disproportionate increase in adverse event Although the antihypertensive effect of PLENDIL is increased at 20 mg once a day',
#   149],
#  ['What were the adverse events reported from controlled clinical trials and during marketing experience?',
#   150],
#  ['What was the incidence of a controlled clinical trial?', 151],
#  ['How many adverse events were reported during marketing?', 152],
#  ['Which are the Serious adverse events reported from controlled clinical trials of PLENDIL and during marketing experience',
#   153],
#  ['What may be accompanied by breathing difficulty?', 154],
#  ['Angioedema caused by PLENDIL is accompanied by what?', 155],
#  ['Which laboratory values statistically significant decreases were observed during PLENDIL treatment?',
#   156],
#  ['Are the decreases laboratory values considered to be of clinical significance ?',
#   157],
#  ['What can cause excessive peripheral vasodilation with marked hypotension and possibly bradycardia?',
#   158],
#  ['What may cause excessive peripheral vasodilation with marked hypotension and possibly bradycardia in PLENDIL treatment',
#   159],
#  ['What do you need to do to manage a suspected drug overdose?', 160],
#  ['How to manage suspected PLENDIL overdose', 161],
#  ['What should be swallowed whole and not crushed or chewed?', 162],
#  ['What should not be administered with a meal rich in carbohydrates or fat?',
#   163],
#  ['Can PLENDIL be crushed or chewed', 164],
#  ['Can Plendil be administered with a meal rich in carbohydrates or fat', 165],
#  ['What is the usual recommended initial dose once daily?', 166],
#  ['Th usual recommended initial dose of PLENDIL', 167],
#  ['What should be adjusted according to the patients response?', 168],
#  ['Depending on what PLENDIL dosage should be adjusted accordingly', 169],
#  ['What is The maintenance dosage range of PLENDIL', 170],
#  ['What did doses above 10 mg daily show in clinical trials?', 171],
#  ['In clinical trials, which dose can cause increased blood pressure response but a disproportionately higher incidence of peripheral edema',
#   172],
#  ['What is the starting dose of felodipine recommended for patients over 65 years?',
#   173],
#  ['Patients of what age may develop elevated plasma concentrations of felodipine.',
#   174],
#  ['What may patients with impaired liver function develop?', 175],
#  ['What is a starting dose of felodipine recommended once daily?', 176],
#  ['Which patients may develop elevated plasma concentrations of felodipine.',
#   177],
#  ['What is usually not required in patients with renal impairment?', 178],
#  ['What is normally not required for renal impairment patients?', 179],
#  ['In which patients Modification of the recommended dosage of PLENDIL is usually not required',
#   180],
#  ['What is the chemical name of PLENDIL', 181],
#  ['Which is the Molecular Formula of PLENDIL', 182],
#  ['What is the solubility of plendil in acetone, dichloromethane, ethanol, heptane, methanol, n- octanol, 2-propanol, and water.',
#   183],
#  ['Is PLENDIL hygroscopic?', 184],
#  ['What are PLENDIL tablets?', 185],
#  ['What is the concentration of felodipine?', 186],
#  ['What are PLENDIL tablets', 187],
#  ['how much felodipine does Plendil has', 188],
#  ['What type of tablet is PLENDIL 2.5 mg?', 189],
#  ['What is the yellow', 190],
#  ['circular', 191],
#  ['biconvex film-coated tablet?', 192],
#  ['On what side is the 2.5 mg tablet engraved?', 193],
#  ['What is the appearance of PLENDIL 2.5 mg Tablet', 194],
#  ['What type of tablet is PLENDIL 5 mg?', 195],
#  ['What is the name of the pink', 196],
#  ['circular', 197],
#  ['biconvex film-coated tablet?', 198],
#  ['What is the appearance of PLENDIL 5 mg Tablet', 199],
#  ['What type of tablet is PLENDIL 10 mg?', 200],
#  ['What is the name of the red-brown', 201],
#  ['circular', 202],
#  ['biconvex film-coated tablet?', 203],
#  ['On what side of the tablet is A/FE printed?', 204],
#  ['What is the appearance of PLENDIL 10 mg Tablet', 205],
#  ['What is each tablet strength available in compliance blister packages?',
#   206],
#  ['How many tablets are available with compliance blister packs?', 207],
#  ['How Each PLENDIL tablet strength is available', 208],
#  ['What should not be divided', 209],
#  ['crushed or chewed?', 210],
#  ['Can Plendil be crushed or chewed?', 211],
#  ['Plendil has shown to lower what in normotensive rats, cats and dogs', 212],
#  ['What was the plasma concentration needed for 20% reduction of mean arterial pressure in normotensive dogs?',
#   213],
#  ['What is the plasma concentration of PLENDIL needed for 20% reduction of mean arterial pressure, in normotensive dogs and spontaneously hypertensive rats',
#   214],
#  ['What were the primary effects of felodipine at plasma concentrations of 1-30 nmol/L?',
#   215],
#  ['What was the only primary effect observed in rats and dogs?', 216],
#  ['What is the only primary effect observed when felodipine is given at plasma concentrations of 1-30 nmol/L',
#   217],
#  ['Based on what Felodipine exhibits a hundredfold vascular versus myocardial selectivity,',
#   218],
#  ['Due to what the reflex tachycardia blocked by beta-adrenoceptor antagonists during maintained antihypertensive treatment of PLENDIL',
#   219],
#  ['What exhibits multiexponentially declining plasma concentration-time curves after i.v. doses?',
#   220],
#  ['What is the binding to plasma proteins in rat', 221],
#  ['dog', 222],
#  ['and man?', 223],
#  ['How did an autoradiography study with (14C) felodipine in mice indicate any irreversible tissue binding?',
#   224],
#  ['What does Felodipine exhibit after I.V does?', 225],
#  ['What does the autoradiography study with (14C) felodipine in mice indicate?',
#   226],
#  ['What is the primary step in the biotransformation of felodipine?', 227],
#  ['What is the primary step in the biotransformation of felodipine', 228],
#  ['How many different inactive metabolites have been identified in rat urine?',
#   229],
#  ['What is the urinary metabolic pattern in mouse', 230],
#  ['rabbit', 231],
#  ['dog and man?', 232],
#  ['How many different inactive metabolites have been identified in rat urine in PLENDIL treatment?',
#   233],
#  ['What are the Signs of acute toxicity of PLENDIL', 234],
#  ['What has been studied after repeated oral administration in rats and dogs?',
#   235],
#  ['When was The general toxicity of felodipine has been studied', 236],
#  ['What has Felodipine not shown?', 237],
#  ['What is the name of the substance that has not shown any mutagenic potential?',
#   238],
#  ['Does Felodipine has any mutagenic potential?', 239],
#  ['How many neoplasms were found in animals dying before termination of the study?',
#   240],
#  ['Why was it necessary to analyze pre-terminal and terminal deaths together to evaluate the carcinogenic potential of felodipine in mice?',
#   241],
#  ['What was the difference between treated and untreated groups?', 242],
#  ['Why Few neoplasms (10 in total; 6 in the treatment groups, 4 in controls) were found in animals dying before termination of the study of PLENDIL',
#   243],
#  ['What study was subjected to a further statistical analysis?', 244],
#  ['In view of the differing survival patterns in the different dose groups, the mouse carcinogenicity study was subjected to what?',
#   245],
#  ['What are the conclusion of The liver slides from mouse carcinogenicity study',
#   246],
#  ['In what study was an increased incidence of benign interstitial cell tumours found?',
#   247],
#  ['In vivo and in vitro studies', 248],
#  ['what indicate there is an endocrinological mechanism behind the increase incidence of Leydig cells in rats?',
#   249],
#  ['What are the results of rat carcinogenicity study of plendil?', 250],
#  ['Which tumours have an endocrinological basis in the rat as they can be induced by various experimental interventions',
#   251],
#  ['Treated and untreated rats in the carcinogenicity study also differed with respect to what?',
#   252],
#  ['How many mg of felodipine does each tablet contain?', 253],
#  ['How many mg of felodipine does each tablet contain', 254],
#  ['Which tablet contains 28 mg lactose and 2.5 mg macrogolglycerol hydroxystearate?',
#   255],
#  ['PLENDIL tablet consist how much lactose and macrogolglycerol hydroxystearate',
#   256],
#  ['How many mg of felodipine does each tablet contain?', 257],
#  ['How much mg Felodipine does PLENDIL contain', 258],
#  ['Which tablet contains 28 mg lactose and 5 mg macrogolglycerol hydroxystearate?',
#   259],
#  ['PLENDIL tablet consist how much lactose and macrogolglycerol hydroxystearate',
#   260],
#  ['How many mg of felodipine does each tablet contain?', 261],
#  ['How much mg Felodipine does PLENDIL contain', 262],
#  ['Which tablet contains 28 mg lactose and 10 mg macrogolglycerol hydroxystearate?',
#   263],
#  ['PLENDIL tablet consist how much lactose and macrogolglycerol hydroxystearate',
#   264],
#  ['What is the diameter of Plendil 2.5 mg?', 265],
#  ['What is the appearance of Plendil 2.5 mg', 266],
#  ['What is Plendil 5 mg?', 267],
#  ['What is the diameter of the tablet?', 268],
#  ['What is the appearance Plendil 5 mg', 269],
#  ['What is Plendil 10 mg?', 270],
#  ['What is the diameter of the tablet?', 271],
#  ['What is the appearance Plendil 10 mg', 272],
#  ['What is not needed in patients with impaired renal function?', 273],
#  ['W', 274],
#  ['In patients whith what diesese Plendil Dose adjustment is not needed', 275],
#  ['Which patients may have elevated plasma concentrations of felodipine', 276],
#  ['Is there any clinical trial experience of the use of felodipine in hypertensive paediatric patients',
#   277],
#  ['How felodipine can be administered?', 278],
#  ['Why felodipine tablets must not be divided, crushed or chewed.', 279],
#  ['What is the efficacy and safety of felodipine in treating hypertensive emergencies?',
#   280],
#  ['What is the The efficacy and safety of felodipine in the treatment of hypertensive emergencies',
#   281],
#  ['What may cause significant hypotension with subsequent tachycardia?', 282],
#  ['What may lead to myocardial ischaemia in susceptible patients?', 283],
#  ['what may lead to myocardial ischaemia in susceptible patients of PLENDIL study?',
#   284],
#  ['What is cleared by the liver?', 285],
#  ['What can be expected in patients with clearly reduced liver function?',
#   286],
#  ['How Felodipine is cleared', 287],
#  ['What is a result of a combination of drugs that induce or inhibit CYP3 A4 enzymes?',
#   288],
#  ['What is another reason for avoiding combinations of drugs?', 289],
#  ['Concomitant administration of drugs that strongly induce or inhibit CYP3 A4 enzymes with PLENDIL results in what?',
#   290],
#  ['What contains lactose?', 291],
#  ['Why Patients with rare hereditary problems of galactose intolerance should not take PLENDIL?',
#   292],
#  ['What can cause stomach upset and diarrhoe?', 293],
#  ['why plendil may cause stomach upset and diarrhoea.', 294],
#  ['What has been reported in patients with pronounced gingivitis/periodontitis?',
#   295],
#  ['What can be avoided or reversed by careful oral hygiene?', 296],
#  ['In which patients taking PLENDIL Mild gingival enlargement has been reported',
#   297],
#  ['How gingival enlargement can be avoided during PLENDIL treatment?', 298],
#  ['What has been reported in patients with pronounced gingivitis/periodontitis?',
#   299],
#  ['What can be avoided or reversed by careful oral hygiene?', 300],
#  ['In which patients taking PLENDIL Mild gingival enlargement has been reported',
#   301],
#  ['How gingival enlargement can be avoided during PLENDIL treatment?', 302],
#  ['What may influence on the plasma level of felodipine', 303],
#  ['What enzyme inhibitors have been shown to cause an increase in felodipine plasma concentrations?',
#   304],
#  ['How manyfold did Felodipines Cmax and AUC increase when coadministered with itraconazole?',
#   305],
#  ['What have been shown to cause an increase in felodipine plasma concentrations.',
#   306],
#  ['To what fold Felodipine Cmax and AUC is increased', 307],
#  ['What happens when felodipine and erythromycin were coadministered', 308],
#  ['How Cimetidine increases the felodipine Cmax', 309],
#  ['What should not be taken together with grapefruit juice?', 310],
#  ['How should Felodipine tablets be taken?', 311],
#  ['Can Felodipine tablets be taken together with grapefruit juice', 312],
#  ['What are enzyme inducers of the cytochrome P450 3A4 system shown to cause a decrease in plasma concentrations of felodipine?',
#   313],
#  ['What was coadministered with carbamazepine', 314],
#  ['phenytoin or phenobarbital?', 315],
#  ['What is shown to cause a decrease in plasma concentrations of felodipine',
#   316],
#  ['What happens when felodipine was coadministered with carbamazepine, phenytoin or phenobarbita',
#   317],
#  ['What may increase the concentration of tacrolimus?', 318],
#  ['What happpens when PLENDIL is used together with Tacrolimus?', 319],
#  ['Does Felodipine affect plasma concentrations of cyclosporin.', 320],
#  ['What should not be given during pregnancy?', 321],
#  ['Can Felodipine be given during pregnancy', 322],
#  ['What has been detected in breast milk?', 323],
#  ['What is not recommended during breast-feeding?', 324],
#  ['Why PLENDIL treatment is not recommended during breast-feeding.', 325],
#  ['What is the effect of felodipine on patient fertility?', 326],
#  ['In a non-clinical reproductive study in the rat', 327],
#  ['there were effects on foetal development but no effect on what?', 328],
#  ['What are the effects of felodipine on patient fertility', 329],
#  ['What influence does Felodipine have on the ability to drive and use machines?',
#   330],
#  ['Does Felodipine has minor or moderate influence on the ability to drive and use machines',
#   331],
#  ['What can cause flushing', 332],
#  ['headache', 333],
#  ['palpitations', 334],
#  ['dizziness and fatigue?', 335],
#  ['What are the adverse reactions of Felodipine', 336],
#  ['Dose-dependent ankle swelling can occur in patients treated with what?',
#   337],
#  ['What is the result of precapillary vasodilatation during PLENDIL treatmen?',
#   338],
#  ['What has been reported in patients with pronounced gingivitis/periodontitis?',
#   339],
#  ['What can be avoided or reversed by careful oral hygiene?', 340],
#  ['In which patients taking PLENDIL Mild gingival enlargement has been reported',
#   341],
#  ['How gingival enlargement can be avoided during PLENDIL treatment?', 342],
#  ['What has been reported in patients with pronounced gingivitis/periodontitis?',
#   343],
#  ['What can be avoided or reversed by careful oral hygiene?', 344],
#  ['In which patients taking PLENDIL Mild gingival enlargement has been reported',
#   345],
#  ['How gingival enlargement can be avoided during PLENDIL treatment?', 346],
#  ['What may cause excessive peripheral vasodilatation with marked hypotension and sometimes bradycardia?',
#   347],
#  ['What may PLENDIL Overdosage Cause', 348],
#  ['If justified: activated charcoal', 349],
#  ['gastric lavage if performed within what hour after ingestion?', 350],
#  ['What should be performed within one hour after PLENDIL ingestion', 351],
#  ['If severe hypotension occurs', 352],
#  ['what should be instituted?', 353],
#  ['What should be done if symptomatic treatment occurs?', 354],
#  ['What if severe hypotension occurs during PLENDIL treatment', 355],
#  ['If severe hypotension occurs', 356],
#  ['what should be instituted?', 357],
#  ['What should be done if symptomatic treatment occurs?', 358],
#  ['What if severe hypotension occurs during PLENDIL treatment', 359],
#  ['If severe hypotension occurs', 360],
#  ['what should be instituted?', 361],
#  ['What should be done if symptomatic treatment occurs?', 362],
#  ['What if severe hypotension occurs during PLENDIL treatment', 363],
#  ['What is Pharmacotherapeutic group od PLENDIL', 364],
#  ['What is Felodipine?', 365],
#  ['How does Felidipine lower arterial blood pressure?', 366],
#  ['By what method does PLENDIL lowers arterial blood pressure', 367],
#  ['Why felodipine in therapeutic doses has no direct effect on cardiac contractility or conduction',
#   368],
#  ['Is felodipine is not associated with orthostatic hypotension', 369],
#  ['What natriuretic effect does Felodipine have?', 370],
#  ['Does fluid retention occur in PLENDIL treatment', 371],
#  ['How Felodipine has anti-anginal and anti-ischaemic effects', 372],
#  ['Due to what the Coronary vascular resistance is decreased and coronary blood flow and myocardial oxygen supply are increased by felodipine',
#   373],
#  ['What leads to decreased left ventricular afterload and myocardial oxygen demand in PLENDIL treatment?',
#   374],
#  ['What is the primary haemodynamic effect of felodipine?', 375],
#  ['What causes a decrease in blood pressure?', 376],
#  ['How long does the trough/peak ratio last?', 377],
#  ['Which is the the primary haemodynamic effect of felodipine', 378],
#  ['What are plasma concentrations of felodipine positively correlated with?',
#   379],
#  ['Plasma concentrations of felodipine are positively correlated to what',
#   380],
#  ['What does Felodipine in therapeutic doses have no effect on?', 381],
#  ['Does Felodipine in therapeutic doses has any effect on cardiac contractility',
#   382],
#  ['Antihypertensive treatment with what is associated with significant regression of pre-existing left ventricular hypertrophy?',
#   383],
#  ['Antihypertensive treatment with felodipine is associated with what?', 384],
#  ['Felodipine has a natriuretic and diuretic effect due to what?', 385],
#  ['What is a result of a reduced tubular reabsorption of filtered sodium?',
#   386],
#  ['How is the renal vascular resistance decreased?', 387],
#  ['Due to what Felodipine has a natriuretic and diuretic effect', 388],
#  ['How does felodipine reduce blood pressure in renal transplant recipients?',
#   389],
#  ['What is the glomerular filtration rate of cyclosporin-treated renal transplant recipient?',
#   390],
#  ['In which patients felodipine reduces blood pressure and improves both the renal blood flow and the glomerular filtration rate.',
#   391],
#  ['Can Felodipine may also improve early renal graft function', 392],
#  ['In a randomised', 393],
#  ['double-blind', 394],
#  ['3-week', 395],
#  ['parallel group study in children aged 6-16 years with primary hypertension',
#   396],
#  ['what was compared with placebo?', 397],
#  ['What did the study fail to demonstrate?', 398],
#  ['Which study failed to demonstrate the efficacy of felodipine in lowering blood pressure in children aged 6-16 years',
#   399],
#  ['What has the long-term effects of felodipine on growth', 400],
#  ['puberty and general development not been studied?', 401],
#  ['What is the long term efficacy of antihypertensive therapy as therapy in childhood?',
#   402],
#  ['Is the The long-term effects of felodipine on growth, puberty and general development have been studied',
#   403],
#  ['What is Felodipine administered as?', 404],
#  ['How long is the absorption phase of the extended-release tablets?', 405],
#  ['When is the maximum blood plasma levels achieved?', 406],
#  ['How Felodipine is administered as ?', 407],
#  ['What is the percentage of systemic availability of felodipine', 408],
#  ['How much is the plasma protein binding of felodipine?', 409],
#  ['What fraction is it bound pre-dominant to?', 410],
#  ['What is the percentage of The plasma protein binding of felodipine', 411],
#  ['How is Felodipine extensively metabolised in the liver?', 412],
#  ['Felodipine is extensively metabolised in the liver by which enzyme?', 413],
#  ['What kind of medicinal product Felodipine is', 414],
#  ['What is the plasma concentration of felodipine in older patients?', 415],
#  ['What is not changed in patients with renal impairment?', 416],
#  ['Which patients have average higher plasma concentrations of felodipine than younger patients.',
#   417],
#  ['How long is the half-life of felodipine in the elimination phase?', 418],
#  ['What percentage of a given dose is excreted as metabolites in the urine?',
#   419],
#  ['What is the half life of felodipine in the elimination phase', 420],
#  ['How much percentage of felodipine is excreted as metabolites in the urine;',
#   421],
#  ['How much percentage of felodipine is excreted as metabolites in the feces',
#   422],
#  ['How much percentage of felodipine is recovered unchanged in urine.', 423],
#  ['What was a relationship between the age and AUC', 424],
#  ['Cmax or half-life of felodipine?', 425],
#  ['In a single dose pharmacokinetic study is there any apparent relationship between the age and AUC, Cmax or half-life of felodipine.',
#   426],
#  ['In a study on fertility and general reproductive performance', 427],
#  ['what resulted in difficult labour/increased foetal deaths and early postnatal deaths?',
#   428],
#  ['What effect was attributed to the inhibitory effect of felodipine in high doses on uterine contractility?',
#   429],
#  ['What are the results of study on fertility and general reproductive performance in rats treated with felodipine',
#   430],
#  ['What was induced in the foetuses when felodipine was administered during early foetal development?',
#   431],
#  ['In monkeys', 432],
#  ['an abnormal position of the distal phalange was noticed in what study?',
#   433],
#  ['What does the Reproduction studies of PLENDIL in rabbits have shown', 434],
#  ['What does the Reproduction studies of PLENDIL monkeys, an abnormal position have shown',
#   435],
#  ['What is considered to be related to the pharmacological action of felodipine when given to normotensive animals?',
#   436],
#  ['Was There any other pre-clinical findings onplendil study considered to be of concern',
#   437],
#  ['Is there any reported clinical incidences of phalangeal changes in foetus/neonate exposed to felodipine in-utero',
#   438],
#  ['What is the shelflife of Prolonged-release tablets 5 mg PLENDIL', 439],
#  ['What is the shelflife of Prolonged-release tablets 10 mg PLENDIL', 440],
#  ['What is a medicinal product that does not require special storage conditions?',
#   441],
#  ['Does PLENDIL require any storage condition?', 442],
#  ['What should be disposed of in accordance with local requirements?', 443],
#  ['How plendil can be disposed?', 444],
#  ['What should be disposed of in accordance with local requirements?', 445],
#  ['How plendil can be disposed?', 446],
#  ['What is a racemic mixture of ethyl methyl 4-(2', 447],
#  ['3- dichlorophenyl)-1', 448],
#  ['4-dihydro 2', 449],
#  ['6-dimethyl-3', 450],
#  ['5 pyridine dicarboxylate?', 451],
#  ['What does the PLENDIL ER tablets contain', 452],
#  ['What are the inactive ingredients of PLENDIL', 453],
#  ['How plendil lowers lowers arterial blood pressure', 454],
#  ['What natriuretic effect does Felodipine have?', 455],
#  ['why plendil does not produce any general fluid retention', 456],
#  ['What is Felodipine effective in all grades of hypertension?', 457],
#  ['What can be combined with other antihypertensives', 458],
#  ['such as beta-receptor blockers', 459],
#  ['diuretics or ACE-inhibitors?', 460],
#  ['Can PLENDIL be be combined with other antihypertensives, such as beta-receptor blockers, diuretics or ACE-inhibitors, in order to achieve an increased antihypertensive effect.',
#   461],
#  ['What has antianginal and anti-ischaemic effects due to improved oxygen supply/demand balance of the myocardium?',
#   462],
#  ['What causes the reduction in systemic blood pressure caused by felodipine?',
#   463],
#  ['Due to what Felodipine has antianginal and anti-ischaemic effects', 464],
#  ['What is the effect of PLENDIL on oxygen supply?', 465],
#  ['What leads to decreased left ventricular afterload and myocardial oxygen demand in PLENDIL tretment',
#   466],
#  ['What is the predominant pharmacodynamic feature of felodipine?', 467],
#  ['Smooth muscles in arterial resistance vessels which exhibit myogenic activity are particularly sensitive to what?',
#   468],
#  ['What inhibits electrical and contractile activity of vascular smooth muscle cells via an action at the cell membrane?',
#   469],
#  ['What is the predominant pharmacodynamic feature of felodipine', 470],
#  ['Via what action Felodipine inhibits electrical and contractile activity of vascular smooth muscle cells',
#   471],
#  ['What is completely absorbed from the gastrointestinal tract after administration of PLENDIL ER tablets?',
#   472],
#  ['Can Felodipine be completely absorbed from the gastrointestinal tract',
#   473],
#  ['Within what hours the Peak plasma concentrations following PLENDIL ER tablets are usually reached',
#   474],
#  ['What is the systemic availability of felodipine independent of?', 475],
#  ['How much bioavailability of the extended release dosage form is due to pre-systemic metabolism?',
#   476],
#  ['Is the systemic availability of felodipine is independent of dose in the therapeutic dose range',
#   477],
#  ['Why the bioavailability of the extended release dosage form (PLENDIL ER) is approximately 20%.',
#   478],
#  ['What produces a relatively flat plasma concentration vs time curve?', 479],
#  ['What does PLENDIL ER maintain over 24 hours after dosing?', 480],
#  ['What are the charecteristics of plasma concentration vs time curve which is produced by PLENDIL',
#   481],
#  ['How much is the plasma protein binding of felodipine in man?', 482],
#  ['what is the percentage of plasma protein binding of felodipine in man',
#   483],
#  ['To which proteien does the Felodipine bind?', 484],
#  ['What is the volume of distribution of felodipine in man?', 485],
#  ['What is the volume of distribution od felodipine in man', 486],
#  ['How is Felodipine extensively metabolised in the liver?', 487],
#  ['What is cytochrome P450 3A4?', 488],
#  ['How much of a given dose is excreted as metabolites in the urine?', 489],
#  ['How Felodipine is metabolised', 490],
#  ['How are the identified metabolites of felodipine?', 491],
#  ['Aproximately how much percentage of metabolites of PLENDIL are excreted in the urine',
#   492],
#  ['How much percentage of Felodipine recovered unchanged in urine.', 493],
#  ['What type of plasma concentrations of felodipine tend to be higher in elderly patients than young healthy individuals?',
#   494],
#  ['What can be attributed to a decrease in plasma half-life?', 495],
#  ['In which pateients the Average peak plasma concentrations of felodipine tend to be higher',
#   496],
#  ['What does the systemic availability', 497],
#  ['time to peak plasma concentration and volume of distribution appear to be affected by?',
#   498],
#  ['What is not appear to be significantly affected by age', 499],
#  ['How should the dosage for all patients be adjusted?', 500],
#  ['Why dosage of PLENDIL ER for all patients should be individually adjusted rather than based solely on patient age.',
#   501],
#  ['What is the acute haemodynamic effect of felodipine?', 502],
#  ['What causes a decrease in blood pressure and a slight and transient reflex increase in heart rate and cardiac output?',
#   503],
#  ['How long does the effect last at steady state?', 504],
#  ['What is The acute haemodynamic effect of felodipine', 505],
#  ['What is the difference between plasma concentrations of felodipine and blood pressure?',
#   506],
#  ['Are Plasma concentrations of felodipine and change in total peripheral resistance and blood pressure are correleated?',
#   507],
#  ['What has no negative effect on cardiac contractility?', 508],
#  ['Antihypertensive treatment with what is associated with regression of pre-existing left ventricular hypertrophy?',
#   509],
#  ['Does Felodipine in therapeutic doses has any effect on conduction in the specialised conducting system',
#   510],
#  ['Antihypertensive treatment with felodipine is associated with is associated with what?',
#   511],
#  ['What is reduced in the distal tubules and collecting ducts in the kidney?',
#   512],
#  ['Does Felodipine has a natriuretic effect', 513],
#  ['Does Felodipine has a diuretic effect', 514],
#  ['What does the Studies of PLENDIL in rats have shown regarding reabsorption of filtered sodium',
#   515],
#  ['What is decreased by felodipine?', 516],
#  ['In normal renal function', 517],
#  ['what is unchanged in glomerular filtration rate?', 518],
#  ['Felodipine decreases which resistance?', 519],
#  ['Is glomerular filtration rate is changed during PLENDIL treatment', 520],
#  ['What decreases peripheral vascular resistance?', 521],
#  ['What is recommended for patients already taking medications that lower blood pressure?',
#   522],
#  ['How can Felodipine cause hypotension in susceptible individuals?', 523],
#  ['Why careful monitoring of blood pressure during the initial administration and titration of felodipine is suggested',
#   524],
#  ['In which patients the use of felodipine result in myocardial ischaemia',
#   525],
#  ['How can a reduction in blood pressure lead to increased frequency', 526],
#  ['duration and severity of angina?', 527],
#  ['Why the the possibility of precipitation of myocardial ischaemia exists during plendil treatment?',
#   528],
#  ['In which patients in plendil study Beta-blockers are contraindicated', 529],
#  ['In which animals An increased incidence of benign interstitial cell testicular tumours has been observed',
#   530],
#  ['Does felodipine has any influence on testosterone formation or on luteinising hormone secretion.',
#   531],
#  ['What should be used with caution in the presence of fixed left ventricular outflow obstruction?',
#   532],
#  ['What should be used with caution in the presence of fixed left ventricular outflow obstruction',
#   533],
#  ['In which patients felodipine is less likely to precipitate pulmonary oedema.',
#   534],
#  ['What percentage of patients treated with felodipine may have a mild to moderate peripheral oedema?',
#   535],
#  ['What is the effect of a diuretic on a peripheral hemorrhage?', 536],
#  ['In how much percetage of patients Mild to moderate peripheral oedema resulting from precapillary vasodilation may occur',
#   537],
#  ['In which patients Felodipine plasma levels are higher', 538],
#  ['What should not be used in paediatric patients due to limited clinical trial experience?',
#   539],
#  ['What type of patient should not use felodipine?', 540],
#  ['Why elodipine should not be used in paediatric patients.', 541],
#  ['What should not be given to pregnant women or those likely to become pregnant?',
#   542],
#  ['Why PLENDIL ER should not be given to pregnant women or those likely to become pregnant.',
#   543],
#  ['In which animal morphological abnormalities of the phalanges were observed during PLENDIL treatment?',
#   544],
#  ['How much did oral doses of felodipine increase in rats?', 545],
#  ['Which does of felodipine caused prolongation of labour in rats', 546],
#  ['When taken in therapeutic doses by the nursing mother', 547],
#  ['what is unlikely to affect the infant?', 548],
#  ['Is Felodipine detected in breast milk', 549],
#  ['Does Felodipine have any effect on the infant', 550],
#  ['Is there any data on fertility in PLENDIL treatment is avalilable?', 551],
#  ['What does PLENDIL ER contain?', 552],
#  ['What should not be given to patients with hereditary galactose intolerance?',
#   553],
#  ['Why PLENDIL should not be given to patients with hereditary galactose intolerance or glucose-galactose malabsorption.',
#   554],
#  ['What may affect plasma concentrations of felodipine?', 555],
#  ['what may affect the the plasma concentrations of felodipine.', 556],
#  ['What are enzyme inhibitors of the cytochrome P450 3A4 system?', 557],
#  ['What are the Enzyme inhibitors of the cytochrome P450 3A4 system', 558],
#  ['What will cause a decrease in plasma levels of felodipine.', 559],
#  ['What was not observed during concomitant treatment with felodipine extended release tablets?',
#   560],
#  ['What is PLENDIL ER?', 561],
#  ['What happens on concomitant treatment of digoxin with felodipine extended release (PLENDIL ER) tablets.',
#   562],
#  ['What happens when PLENDIL ER was given with food', 563],
#  ['What has been shown to increase the bioavailability of dihydropyridines?',
#   564],
#  ['What happens on cocammittant administraion of LENDIL with Grapefruit juice',
#   565],
#  ['What may increase the concentration of tacrolimus?', 566],
#  ['can Felodipine increase the concentration of tacrolimus', 567],
#  ['What may increase the concentration of tacrolimus?', 568],
#  ['can Felodipine increase the concentration of tacrolimus', 569],
#  ['In what country has PLENDIL ER been studied extensively?', 570],
#  ['What type of therapy has been extensively studied in Australia and overseas?',
#   571],
#  ['Is PLENDIL ER has been extensively studied in Australia and overseas', 572],
#  ['What can cause flushing', 573],
#  ['peripheral oedema', 574],
#  ['headache', 575],
#  ['palpitations', 576],
#  ['dizziness and fatigue?', 577],
#  ['Which adverse reactions of PLENDIL are usually transient and diminish in intensity with time.',
#   578],
#  ['How can ankle swelling occur in patients treated with felodipine?', 579],
#  ['What is the cause of ankle swelling?', 580],
#  ['As with other dihydropyridines, what can occur in patients treated with felodipine.',
#   581],
#  ['What has been reported in patients with pronounced gingivitis or peridontitis?',
#   582],
#  ['What can be avoided or reversed by attention to dental hygiene?', 583],
#  ['As with other calcium antagonists, is gingival enlargement has been reported in patients with pronounced gingivitis or peridontitis.',
#   584],
#  ['What has been noted during felodipine treatment?', 585],
#  ['Which laboratory abnormalities have not been associated with clinical symptoms during felodipine treatment',
#   586],
#  ['What type of adverse event was rarely reported in patients receiving felodipine in placebo-controlled studies?',
#   587],
#  ['Which serious adverse events were reported rarely in patients receiving felodipine in placebo-controlled',
#   588],
#  ['What is the starting does of felodipine In elderly patients', 589],
#  ['What can be increased in 2.5 or 5mg/day increments?', 590],
#  ['What is the usual maintenance dose?', 591],
#  ['What is the usual maitainance does of PLENDIL', 592],
#  ['What should PLENDIL ER tablets be swallowed whole and taken with water?',
#   593],
#  ['What should not be divided', 594],
#  ['crushed or chewed?', 595],
#  ['How PLENDIL ER tablets should be taken', 596],
#  ['Can PLENDIL ER tablets be crushed?', 597],
#  ['What should not be used in paediatric patients due to limited clinical trial experience?',
#   598],
#  ['Why felodipine should not be used in paediatric patients', 599],
#  ['What should be reduced in patients with severely impaired liver function?',
#   600],
#  ['In which patients The dose of felodipine should be reduced', 601],
#  ['What does impaired renal function not influence?', 602],
#  ['What is not necessary for patients with renal impairment?', 603],
#  ['Does Impaired renal function influence felodipine peak plasma concentrations or AUC',
#   604],
#  ['What may cause excessive peripheral vasodilation with marked hypotension and sometimes bradycardia?',
#   605],
# ...
#   834],
#  ['What was the most common adverse event that led to treatment discontinuation?',
#   835],
#  ['In the JUPITER trial, how much percentage of placebo and rosuvastatin subjects discontinued use of study medication',
#   836],
#  ['What are the most common adverse drug reactions which are seen during JUPITER trial of crestor',
#   837],
#  ['Which rosuvastatin dosage given in a double-blind, randomised, multi-centre, placebo-controlled, 12-week study',
#   838],
#  ['Which rosuvastatin dosage given in a 40-week (n=173, 96 male and 77 female), open-label, rosuvastatin dose-titration phase',
#   839],
#  ['What percentage of LDL-C was reduced by rosuvastatin 5', 840],
#  ['10 and 20 mg?', 841],
#  ['By how much percentage the LDL-C was reduced by rosuvastatin', 842],
#  ['How many patients achieved the LDL-C goal at the end of the 40-week', 843],
#  ['open-label', 844],
#  ['titration to goal?', 845],
#  ['How many of the patients had achieved what goal of less than 2.8 mmol/L?',
#   846],
#  ['How many pateints had achieved the LDL-C goal of less than 2.8 mmol/L At the end of the 40-week, open-label, titration to goal study',
#   847],
#  ['After how many weeks of study crestor treatment, no effect on growth, weight, BMI or sexual maturation was detected',
#   848],
#  ['What is the starting dose for all patients in 2-year open-label, titration-to-goal study in 198 children with heterozygous familial hypercholesterolaemia aged 6 to 17 years',
#   849],
#  ['After 24 months of treatment with rosuvastatin, what is the the LS mean percent reduction from the baseline value in LDL-C',
#   850],
#  ['What did Rosuvastatin achieve statistically significant mean changes from baseline for?',
#   851],
#  ['For which secondary lipid and lipoprotein variables Rosuvastatin 5 mg, 10 mg, and 20 mg also achieved statistically significant mean changes from baseline',
#   852],
#  ['Is there any effect on growth, weight, BMI or sexual maturation was detected after 24 months of crestor treatment',
#   853],
#  ['What was studied in a randomised', 854],
#  ['double-blind', 855],
#  ['placebo-controlled', 856],
#  ['multi-centre', 857],
#  ['cross-over study?', 858],
#  ['How many children and adolescents were diagnosed with homozygous familial hypercholesterolaemia?',
#   859],
#  ['What was the active 4-week dietary lead-in phase during which patients were treated with rosuvastatin 10 mg?',
#   860],
#  ['What are the results of randomised, double-blind, placebo-controlled, multi-centre, cross-over study with 20 mg crestor once daily versus placebo in 14 children and adolescents (aged from 6 to 17 years) with homozygous familial hypercholesterolaemia.',
#   861],
#  ['What was a statistically significant reduction in LDL-C after 6 weeks of treatment with rosuvastatin 20 mg versus placebo?',
#   862],
#  ['What percentage of patients had a further reduction of LDL C', 863],
#  ['Total-C', 864],
#  ['and Non-HDL-C?', 865],
#  ['A statistically significant reduction in LDL-C was observed following how many weeks of treatment with rosuvastatin',
#   866],
#  ['How many patients were treated with 20 mg rosuvastatin for up to 90 weeks?',
#   867],
#  ['What are the results of extended open-label treatment of crestor', 868],
#  ['What are the result of force-titration open label study with homozygous familial hypercholesterolaemia',
#   869],
#  ['The European Medicines Agency has waived the obligation to submit the results which studies?',
#   870],
#  ['How long after oral administration is the maximum rosuvastatin plasma concentration achieved?',
#   871],
#  ['How long is the absolute bioavailability?', 872],
#  ['At what time Maximum rosuvastatin plasma concentrations are achieved ?',
#   873],
#  ['What is absolute bioavailability of rosuvastatin', 874],
#  ['What is the primary site of cholesterol synthesis and LDL-C clearance?',
#   875],
#  ['How much of rosuvastatin is bound to plasma proteins?', 876],
#  ['Which is the primary site of cholesterol synthesis and LDL- C clearance',
#   877],
#  ['How much is the volume of distribution of rosuvastatin', 878],
#  ['Aproximately how much percentage of rosuvastatin is bound to plasma proteins',
#   879],
#  ['What percentage of the circulating HMG-CoA reductase inhibitor activity does Rosuvastatin undergo?',
#   880],
#  ['How rosuvastatin is metabolised?', 881],
#  ['Which are the main metabolites of rosuvastatin?', 882],
#  ['Rosuvastatin accounts for how much percent of circulating HMG-CoA reductase inhibitor activity.',
#   883],
#  ['What percentage of the rosuvastatin dose is excreted unchanged in the faeces?',
#   884],
#  ['How long is the plasma elimination half-life?', 885],
#  ['What is the geometric mean plasma clearance?', 886],
#  ['Approximately how much percent of the rosuvastatin dose is excreted unchanged in the faeces',
#   887],
#  ['Approximately how much percent of the rosuvastatin dose is excreted unchanged in the urine',
#   888],
#  ['What is the The plasma elimination half-life of crestor', 889],
#  ['What increases in proportion to dose?', 890],
#  ['In propotion to what the Systemic exposure of rosuvastatin increases', 891],
#  ['What is the average elevation in median AUC and Cmax in Asian subjects?',
#   892],
#  ['A population pharmacokinetic analysis revealed what?', 893],
#  ['What does the Pharmacokinetic studies on rosuvastatin show', 894],
#  ['what does a population pharmacokinetic analysis reveal?', 895],
#  ['In a study in subjects with varying degrees of renal impairment', 896],
#  ['what had no influence on plasma concentration of rosuvastatin or the N-desmethyl metabolite?',
#   897],
#  ['Is there any crestor influence on plasma concentration of rosuvastatin or the N-desmethyl metabolite',
#   898],
#  ['Was there any evidence of increased exposure to rosuvastatin in subjects with Child-Pugh scores of 7 or below.',
#   899],
#  ['What does the disposition of HMG-CoA reductase inhibitors involve?', 900],
#  ['What is the risk of increased rosuvastatin exposure in patients with SLCO1B1 and/or ABCG2 genetic polymorphisms?',
#   901],
#  ['Individual polymorphisms which genes are associated with a higher rosuvastatin exposure (AUC) compared to the SLCO1B1 c.521TT or ABCG2 c.421CC genotypes.',
#   902],
#  ['How many pharmacokinetic studies with rosuvastatin were conducted in paediatric patients?',
#   903],
#  ['What are the results of Two pharmacokinetic studies with rosuvastatin (given as tablets) in paediatric patients with heterozygous familial hypercholesterolaemia 10 to 17 or 6 to 17 years of age (total of 214 patients) ?',
#   904],
#  ['Is the Rosuvastatin exposure was predictable with respect to dose and time over a 2-year period.',
#   905],
#  ['What does the Preclinical data on rosuvastatin reveal', 906],
#  ['Which are the Adverse reactions not observed in clinical studies, but seen in animals at exposure levels similar to clinical exposure levels',
#   907],
#  ['What is CRESTOR indicated as an adjunct to diet for the reduction of?',
#   908],
#  ['In which patients CRESTOR is indicated as an adjunct to diet for the reduction of elevated total cholesterol (Total-C), LDL-C and ApoB',
#   909],
#  ['What is rosuvastatin calcium?', 910],
#  ['What should be done before instituting therapy with CRESTOR?', 911],
#  ['How should the patient be advised to inform subsequent physicians of the prior use of CreSTOR or any other lipid-lowering agent?',
#   912],
#  ['Before instituting therapy with CRESTOR (rosuvastatin calcium), what attempt should be made',
#   913],
#  ['What is the clinical significance of a potential long-term statin-induced deficiency of ubiquinone?',
#   914],
#  ['What could lead to impaired cardiac function in patients with borderline congestive heart failure?',
#   915],
#  ['Why Ubiquinone levels were not measured in CRESTOR clinical trials', 916],
#  ['Rosuvastatin demonstrated no effect upon what levels', 917],
#  ['Is there any impairment of adrenocortical reserve reduction in plasma cortisol concentrations in crestor treated patients?',
#   918],
#  ['Which Patients treated with rosuvastatin should be evaluated appropriately',
#   919],
#  ['Is Increases in fasting glucose and HbA1c levels have been reported with inhibitors of HMG- CoA reductase like crestor?',
#   920],
#  ['Why periodic monitoring of diabetic patients is recommended.', 921],
#  ['In what trial was rosuvastatin used to increase plasma glucose levels?',
#   922],
#  ['What was sufficient to shift some prediabetic subjects to diabetes mellitus status?',
#   923],
#  ['What are the results of JUPITER trial', 924],
#  ['What effect may be partly blunted by a concomitant increase in Lipoprotein(a) concentrations?',
#   925],
#  ['What is an emerging risk factor for coronary heart disease?', 926],
#  ['In some patients how the beneficial effect of lowered total cholesterol and LDL-C levels may be partly blunted ?',
#   927],
#  ['CRESTOR is contraindicated in which patients', 928],
#  ['When CRESTOR should be discontinued', 929],
#  ['Which test hould be carried out prior to, and 3 months following, the initiation of CRESTOR',
#   930],
#  ['In how much percent of patients a dose-related increase in transaminases has been observed',
#   931],
#  ['What has been reported of fatal and nonfatal hepatic failure in patients taking statins?',
#   932],
#  ['If serious liver injury with clinical symptoms and/or hyperbilirubinemia occurs during treatment with CRESTOR',
#   933],
#  ['promptly interrupt what?', 934],
#  ['What if serious liver injury with clinical symptoms and/or hyperbilirubinemia or jaundice occurs during treatment with CRESTOR',
#   935],
#  ['Is there any post-marketing reports of fatal and non-fatal hepatic failure in patients taking statins, including rosuvastatin',
#   936],
#  ['Is there any evidence of increased exposure to rosuvastatin In subjects with varying degrees of hepatic impairment',
#   937],
#  ['Rare cases of rhabdomyolysis with acute renal failure secondary to myoglobinuria have been reported with what?',
#   938],
#  ['What have been reported with CRESTOR and with other HMG-CoA reductase inhibitors.',
#   939],
#  ['Particularly with which dose of crestor Effects on skeletal muscle such as myalgia, myopathy and, rarely, rhabdomyolysis have been reported',
#   940],
#  ['If markedly elevated CK levels are measured', 941],
#  ['what should be discontinued?', 942],
#  ['Which patients should have CK levels measured', 943],
#  ['When CRESTOR therapy should be discontinued', 944],
#  ['Is there any evidence of increased skeletal muscle effects when CRESTOR was dosed with concomitant therapy such as fibric acid derivatives',
#   945],
#  ['What should be temporarily discontinued in a patient with a severe metabolic endocrine and electrolyte disorder?',
#   946],
#  ['In which patients CRESTOR therapy should be temporarily withheld or discontinued',
#   947],
#  ['Why CRESTOR 40 mg is contraindicated in these patients with severe renal impairment',
#   948],
#  ['In subjects with varying degrees of renal impairment', 949],
#  ['mild to moderate renal disease had little influence on what plasma concentrations?',
#   950],
#  ['Does mild to moderate renal disease had any influence on plasma concentrations of rosuvastatin.',
#   951],
#  ['During the clinical development what were observed among rosuvastatin-treated patients,',
#   952],
#  ['What has been seen in patients taking CRESTOR and other HMG-CoA reductase inhibitors.',
#   953],
#  ['What may be considered for patients with unexplained persistent proteinuria during routine testing?',
#   954],
#  ['In which patients a dose reduction Rosuvastatin is recommended?', 955],
#  ['Which has been has been reported rarely with other HMG-CoA reductase inhibitor like crestor',
#   956],
#  ['What are the features of apparent hypersensitivity syndrome which has been reported rarely with other HMG-CoA reductase inhibitors',
#   957],
#  ['Is CRESTOR is contraindicated during pregnancy', 958],
#  ['Why should women taking CRESTOR not breast-feed?', 959],
#  ['Is rosuvastatin is excreted in human milk', 960],
#  ['Why women taking CRESTOR should not breast-feed', 961],
#  ['What was more frequent with increasing CRESTOR dose?', 962],
#  ['In which patients taking crestor Elevations in serum creatine phosphokinase (CK) > 10 x ULN were observed more frequently',
#   963],
#  ['When was CK elevation > 10 x ULN (with or without muscle symptoms) was more frequent',
#   964],
#  ['The evaluation of linear growth (height), weight, BMI (body mass index), and secondary characteristics of sexual maturation by Tanner staging in paediatric patients 6 to 17 years of age taking rosuvastatin is limited how many years?',
#   965],
#  ['Does CRESTOR had any detectable effect on growth or sexual maturation',
#   966],
#  ['What should adolescent females be counselled on while on CRESTOR therapy?',
#   967],
#  ['Which patients should be counselled on appropriate contraceptive methods while on CRESTOR therapy',
#   968],
#  ['Treatment experience with CRESTOR in pediatric patientswith homozygous familial hypercholesterolemia is limited to how many patients?',
#   969],
#  ['Treatment experience with CRESTOR in pediatric patientswith homozygous familial hypercholesterolemia is limited to how many patients?',
#   970],
#  ['What does the Results of pharmacokinetic studies, including a large study conducted in North America indicate?',
#   971],
#  ['What is rosuvastatin calcium?', 972],
#  ['What type of adverse events are seen with CRESTOR?', 973],
#  ['What are the charecteristics of adverse events seen with CRESTOR', 974],
#  ['What is useful for identifying drug-related adverse events and approximating rates?',
#   975],
#  ['Why the adverse drug reaction rates observed in the clinical trials of Crestor may not reflect the rates observed in practice ?',
#   976],
#  ['Why Adverse drug reaction information from clinical trials is useful', 977],
#  ['How many participants were treated with CRESTOR 20 mg once daily (n=8901) or placebo?',
#   978],
#  ['What was the mean duration of the study?', 979],
#  ['How many years were subjects followed for a mean duration?', 980],
#  ['What are theresults of An Intervention Trial Evaluating Rosuvastatin (JUPITER) study of crestor',
#   981],
#  ['In which study CRESTOR was shown to have no harmful effect on the ocular lens.',
#   982],
#  ['Is a dose-related increase in liver transaminases and CK has been observed in a small number of patients taking rosuvastatin',
#   983],
#  ['What type of urinalysis testing has been seen in a small number of patients taking CRESTOR and other HMG-CoA reductase inhibitors?',
#   984],
#  ['During the clinical development what were observed among rosuvastatin-treated patients,',
#   985],
#  ['What has been seen in patients taking CRESTOR and other HMG-CoA reductase inhibitors.',
#   986],
#  ['Does proteinuria decreases or disappears spontaneously on continued therapy of crestor',
#   987],
#  ['The safety profile of CRESTOR in pediatric patients is similar to which patients?',
#   988],
#  ['What was evaluated in a multicentre double-blind', 989],
#  ['placebo-controlled study of pediatric patients with heterozygous familial hypercholesterolemia?',
#   990],
#  ['How many of the pediatric patients treated with CRESTOR had increased CK 10 x ULN compared to how many patients on placebo?',
#   991],
#  ['What are the results of multicentre double-blind, placebo-controlled study of pediatric patients with heterozygous familial hypercholesterolemia.',
#   992],
#  ['How many pediatric patients treated with CRESTOR were treated with myalgia?',
#   993],
#  ['In the 40-week open label titration-to-goal phase, in how much percent of pediatric patients treated myalgia was reported',
#   994],
#  ['What was the difference between ALT and AST values from baseline?', 995],
#  ['What group did CRESTOR and placebo not consider to be clinically significant?',
#   996],
#  ['In which group Mean change in ALT and AST values from baseline were slightly higher',
#   997],
#  ['How many adverse events of depression were reported in pediatric patients treated with CRESTOR 20 mg',
#   998],
#  ['Are all adverse reactions that have been identified in the adult populations have been observed in the clinical trials of pediatric patients',
#   999],
#  ...]

# %%
def rank(ans):
    all_scores=[]
    required=ans['hits']
    main_arr=required["hits"]
    count=1
    ids__=dict()
    for x in main_arr:
        id_no= x["_id"]

        score=x["_score"]
        all_scores.append(score)

        answer_=x["_source"]["answer"]
        
        ids__[id_no.strip()]=1/count
        count+=1
    return [ids__,all_scores]

# %%
ranker=rank(ans)

# %%
ranker
# Out:
# [{'1853': 1.0,
#   '1053': 0.5,
#   '1054': 0.3333333333333333,
#   '640': 0.25,
#   '209': 0.2,
#   '210': 0.16666666666666666,
#   '211': 0.14285714285714285,
#   '612': 0.125,
#   '633': 0.1111111111111111,
#   '634': 0.1},
#  [0.46329686,
#   0.37016562,
#   0.37016562,
#   0.3658487,
#   0.35805935,
#   0.35805935,
#   0.35805935,
#   0.34812328,
#   0.3444973,
#   0.3444973]]

# %%
ans=es.search(index=IndexName,body={"size": 10,"query": script_query,"_source": {"includes": ["answer"]}})

# %%
def mrr():
    total=0
    count=0
    recall_count=0
    lists_all=list_generator()
    score_star=[]
    print(lists_all)
    for i in range(0,len(que_arr)):
        question_=que_arr[i][0].strip()
        print(question_)
        id_number=str(que_arr[i][1])

        script_query_curr=query_creator(question_,lists_all,i)
        ans=es.search(index=IndexName,body={"size": 10,"query": script_query_curr,"_source": {"includes": ["answer","product","country"]}})
        ranker=rank(ans)
        scorer=ranker[1]
        score_star.append(scorer)
        ranker=ranker[0]
        if id_number in ranker:
            total+=ranker[id_number]
            print(ranker[id_number])
            recall_count+=1
        else:
            print(0)
        count+=1

    print("mrr is"+str(total/count))
    print("recall is"+str(recall_count/count))
    return score_star

# %%
scores_man=mrr()
# Out:
# [['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril'], ['european union', 'united states', 'canada']]
# What is a calcium ion influx inhibitor?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# What class of calcium channel blockers is Felodipine a member of?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# felodipine
# 2...........
# 0
# Felodipine is a member of which class of inhibitors?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# felodipine
# 2...........
# 0
# What is the therapeutic effect of Felodipine related to?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# felodipine
# 2...........
# 0
# How are the contractile processes of these tissues dependent upon the movement of extracellular calcium into the cells?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# How does Felodipine blocks transmembrane influx of calcium ?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# felodipine
# 2...........
# 0
# Through what channel Felodipine blocks transmembrane influx of calcium ?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# felodipine
# 2...........
# 0
# What process results in a reduction of free calcium ions available within cells of the tissues like cardiac muscle and vascular smooth muscle
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# What does Felodipine do not alter?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# felodipine
# 2...........
# 0
# In vitro studies show that the effects of what on contractile mechanisms are selective?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# What is the effect on vascular smooth muscle?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# Negative inotropic effects can be detected in what animal?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# How Negative inotropic effects of felodipine can be detected
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# felodipine
# 2...........
# 0
# Does the Negative inotropic effects of felodipine are seen in animals?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# felodipine
# 2...........
# 0
#

# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# How much daily can the dose be?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# What is the maximum dose of the dose?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# Until when the the Zestril dosage may be titrated upward ?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# What can be titrated upward until blood pressure is controlled?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# How much daily can the dose be?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# What is the maximum dose of the dose?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# Until when the the Zestril dosage may be titrated upward ?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# What can be titrated upward until blood pressure is controlled?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# How much daily can the dose be?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# What is the maximum dose of the dose?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# Until when the the Zestril dosage may be titrated upward ?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# What was similar in younger and older patients given similar doses of ZESTRIL?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# What does the Pharmacokinetic studies of zestril indicate?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# Why the dosage adjustments should be made with particular caution in older patients?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# What type of hypertension can some patients develop?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# What is the first dose of ZESTRIL?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# When should treatment be started?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# How is the dosage adjusted?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# Which patients may develop an increased risk of severe hypotension and renal insufficiency to the first dose of ZESTRIL ?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# In which group of patients treatment of zestril should be started at low doses (2.5 or 5 mg), under close medical supervision ?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# Why is the dosage of zestril may be adjusted according to the blood pressure response
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# What is ZESTRIL to be used in conjunction with?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# What must be initiated under close medical supervision?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# Why Blood pressure and renal function should be monitored, both before and during treatment with ZESTRIL ?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# What should be reduced before beginning treatment?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# Of what the Initiation of therapy requires consideration
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# What should be assessed before and during therapy with ZESTRIL?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# What should be assessed before and during therapy with ZESTRIL
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# Dosing should normally continue for what period of time?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# What should patients with signs or symptoms of heart failure continue with?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# For how many weeks Zestril Dosing should normally continue
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# What is compatible with intravenous or transdermal glyceryl trinitrate?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# Is ZESTRIL compatible with intravenous or transdermal glyceryl trinitrate ?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# Can ZESTRIL be recommended in pediatric patients <6 years or with GFR <30 mL/min/1.73 m2 ?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# Which is the Chemical Name of zestril?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# What is the molecular weight of zestril?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# Lisinospril is what kind of powder?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# What is the solublity of lisinopril in water ,methanol and thanol
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# lisinopril
# 2...........
# 0
# How many nonmedicinal ingredients does each tablet contain?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# 4...........
# 0
# How zestril is supplied?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# In addition to themedicinal ingredient lisinopril what are the nonmedicinal ingredients of ZESTRIL?
# ['rosuvastatin', 'crestor', 'plendil', 'felodipine', 'zestril', 'lisinopril']
# ['european union', 'united states', 'canada']
# zestril
# 2...........
# 0
# mrr is4.434589800443459e-05
# recall is0.0004434589800443459

# %%
len(scores_man)
# Out:
# 2255

# %%
with open('/home/srinivas/Desktop/normal/bert_scores','wb') as f:
     pickle.dump(scores_man, f)

# %%
with open('/home/srinivas/Desktop/normal/bert_scores','rb') as f:
     bert_scores=pickle.load( f)

# %%
len(bert_scores)
# Out:
# 2255

# %%
bert_scores
# Out:
# [[0.92457974,
#   0.9173813,
#   0.9173813,
#   0.9173813,
#   0.9156908,
#   0.9156908,
#   0.91367173,
#   0.91367173,
#   0.91367173,
#   0.91367173],
#  [0.9510046,
#   0.9510046,
#   0.9510046,
#   0.9371886,
#   0.9371886,
#   0.9371886,
#   0.93681693,
#   0.93681693,
#   0.9365516,
#   0.9365516],
#  [0.9380361,
#   0.9380361,
#   0.9380361,
#   0.9308792,
#   0.9308792,
#   0.9308792,
#   0.93053323,
#   0.9280719,
#   0.9280719,
#   0.92797637],
#  [0.94505966,
#   0.94505966,
#   0.94201696,
#   0.94201696,
#   0.9405877,
#   0.9405877,
#   0.9405877,
#   0.9401751,
#   0.9401751,
#   0.9401751],
